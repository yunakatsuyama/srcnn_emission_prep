# %% [markdown]
# import numpy as np
# import pandas as pd
# import xarray as xr
# import math

# %%
import numpy as np 
import pandas as pd 
import xarray as xr 
#import math
import matplotlib.pyplot as plt
from cmcrameri import cm
#import cartopy.crs as ccrs
#import cartopy.feature as cfeature
import matplotlib.colors as mcolors
#import matplotlib.image as mpimg
#from scipy.interpolate import RegularGridInterpolator

import xesmf as xe

# %%
ds = xr.open_dataset("Emission_grid_all.nc")

# %%
path2cams = 'CAMS-GLOB-ANT_Glb_0.1x0.1_anthro_nox_v6.2_yearly_2010.nc'
camsds = xr.open_dataset(path2cams)

#camsds = camsds.squeeze().sel(lon=slice(lon_min-1, lon_max+1), lat=slice(lat_min-1, lat_max+1))
print(camsds)
# Out:
# <xarray.Dataset> Size: 363MB
# Dimensions:        (time: 1, lat: 1800, lon: 3600)
# Coordinates:
#   * time           (time) datetime64[ns] 8B 2010-01-01
#   * lat            (lat) float32 7kB -89.95 -89.85 -89.75 ... 89.75 89.85 89.95
#   * lon            (lon) float32 14kB -179.9 -179.9 -179.8 ... 179.8 179.9 179.9
# Data variables: (12/15)
#     agl            (time, lat, lon) float32 26MB ...
#     ags            (time, lat, lon) float32 26MB ...
#     awb            (time, lat, lon) float32 26MB ...
#     com            (time, lat, lon) float32 26MB ...
#     ene            (time, lat, lon) float32 26MB ...
#     fef            (time, lat, lon) float32 26MB ...
#     ...             ...
#     res            (time, lat, lon) float32 26MB ...
#     shp            (time, lat, lon) float32 26MB ...
#     sum            (time, lat, lon) float32 26MB ...
#     swd            (time, lat, lon) float32 26MB ...
#     tnr            (time, lat, lon) float32 26MB ...
#     tro            (time, lat, lon) float32 26MB ...
# Attributes: (12/13)
#     Conventions:        CF-1.6
#     projection:         latlon
#     authors:            A. Soulie and C. Granier
#     description:        Monthly nox expressed as nitric oxide emissions based...
#     product_version:    v6.2
#     title:              CAMS Global anthropogenic emissions
#     ...                 ...
#     source:             EDGARv6 emissions up to 2018 CAMS-GLOB-TEMPOv2.1/v3.2...
#     creation_date:      2023-11-21 UTC
#     NCO:                netCDF Operators version 5.1.4 (Homepage = http://nco...
#     distribution_date:  2025-10-14
#     references:         Soulie, A., Granier, C., Darras, S., Zilbermann, N., ...
#     history:            Tue Oct 14 15:20:07 2025: ncatted -O -a distribution_...

# %%
def centers_to_edges(arr):
    d = np.diff(arr)
    edges = np.empty(len(arr) + 1)
    edges[1:-1] = arr[:-1] + d / 2
    edges[0] = arr[0] - d[0] / 2
    edges[-1] = arr[-1] + d[-1] / 2
    return edges

def get_latlon_array(lat_range,lon_range):  # lon_range = [lon_min, lon_max], lat_range = [lat_min, lat_max]
     
    lat_range = np.array(lat_range)
    lon_range  = np.array(lon_range)
    
    lat_range_grid = np.ceil(lat_range * 120) * 1/120
    lon_range_grid = np.ceil(lon_range * 80) * 1/80

    #print(lat_range_grid)
    #print(lon_range_grid)
    
    lat_array = np.arange(lat_range_grid[0],lat_range_grid[1] + 1/120,  1/120 )
    lon_array  = np.arange(lon_range_grid[0],lon_range_grid[1] + 1/120 ,  1/80 )
    
    lat_array = np.round(lat_array, 5)
    lon_array = np.round(lon_array ,5)

    return lon_array, lat_array

# %%
# the input lon, lat is the center of 5 x 5 grid 
def cams_make(lon, lat, camsds,cams_pix = 5):
  
    # squeeze in case there are time/level dims
    camsds = camsds.squeeze()

    # get full CAMS coordinates
    src_lon = camsds['lon'].values
    src_lat = camsds['lat'].values
    src_val = 1e9 * 1e-2 * camsds['sum'].values  # (nlat, nlon)

    # --- 1. find nearest CAMS grid cell to (lon, lat) ---
    ix0 = np.argmin(np.abs(src_lon - lon))
    iy0 = np.argmin(np.abs(src_lat - lat))

    # --- 2. build 5x5 window around it ---
    half = cams_pix // 2  # =2

    ix = np.arange(ix0 - half, ix0 + half + 1)
    iy = np.arange(iy0 - half, iy0 + half + 1)

    # clip to domain (safety)
    ix = ix[(ix >= 0) & (ix < len(src_lon))]
    iy = iy[(iy >= 0) & (iy < len(src_lat))]

    # actual CAMS grid centers
    cams_lon_array = src_lon[ix]
    cams_lat_array = src_lat[iy]

    # extract CAMS emission subgrid
    cams_emission = src_val[np.ix_(iy, ix)]  # (5,5) if not at boundary

    #print("CAMS lon centers:", cams_lon_array)
    #print("CAMS lat centers:", cams_lat_array)
    #print("CAMS subgrid shape:", cams_emission.shape)
    # plt.imshow(cams_emission)
    # plt.show()
   
    return cams_lon_array, cams_lat_array, cams_emission

# %%
def eagrid_make_xesmf(cams_lon_array, cams_lat_array,cams_emission, k, sector = "All_sources", source = 'NOx'):
    # = make downscaled grid made from original cams grid
    dlon = np.abs(cams_lon_array[1] - cams_lon_array[0])
    dlat = np.abs(cams_lat_array[1] - cams_lat_array[0])

    # build fine grid covering the 5 CAMS cells
    lon_min = cams_lon_array[0] - dlon / 2
    lon_max = cams_lon_array[-1] + dlon / 2
    lat_min = cams_lat_array[0] - dlat / 2
    lat_max = cams_lat_array[-1] + dlat / 2

    fine_dlon = dlon / k
    fine_dlat = dlat / k

    # The lat lon is the center of grid
    eagrid_lon_array = np.round(np.linspace(lon_min + fine_dlon/2, lon_max - fine_dlon/2, 5 * k), 4)
    eagrid_lat_array = np.round(np.linspace(lat_min + fine_dlat/2, lat_max - fine_dlat/2, 5 * k), 4)
    
    # Lon, Lat = np.meshgrid(eagrid_lon_array, eagrid_lat_array)
    # value_grid = np.zeros(Lon.shape, dtype = float)  # data will be stored 
    # area_grid  = np.zeros_like(value_grid) # area of overlap will be stored

    # print(f"cams_lat_array {len(cams_lat_array), cams_lat_array}")
    # print(f" first eagrid_lat_arra {eagrid_lat_array[0]}")
    # print(f" end eagrid_lat_array {eagrid_lat_array[-5:]}")
    # print(f" len of eagrid_lon_array {len(eagrid_lon_array)}")
    # print(f"first of eagrid_lon_array {eagrid_lon_array[:5]}")

    # == From here eagrid data is read == 
    sec_idx = int(ds.sector.to_index().get_loc(sector))
    src_idx = int(ds.source.to_index().get_loc(source))

    lat_e = ds["lat"].values
    lon_e = ds["lon"].values
    emission = ds["Emission"][sec_idx, src_idx, :].values

    # == mask ====
    # get a range from lat_array and lon_array
    margin = 0.05
    lat_min, lat_max = eagrid_lat_array[0], eagrid_lat_array[-1]
    lon_min, lon_max = eagrid_lon_array[0], eagrid_lon_array[-1]
    mask = (lat_e >= lat_min - margin) & (lat_e <= lat_max + margin) & \
           (lon_e >= lon_min - margin) & (lon_e <= lon_max + margin)
    # extract # lat_in, lon_in are left bottom
    lat_in = lat_e[mask]
    lon_in = lon_e[mask]

    emission_in = emission[mask]

    # # only keep points with no multiple values
    # coords = np.column_stack((lon_in,lat_in))
    # _, unique_idx = np.unique(coords, axis=0, return_index=True)

    # lon_in = lon_in[unique_idx]
    # lat_in = lat_in[unique_idx]
    # emission_in = emission_in[unique_idx]

    # TODO currently hard-corded, needs to be revisited
    #dlat_e = 1/240
    #dlon_e = 1/160
    lon_e_edges , lat_e_edges = get_latlon_array([lat_min , lat_max ],[lon_min , lon_max])  #
    lon_e_center = lon_e_edges + 1/160
    lat_e_center = lat_e_edges + 1/240

    # add the right top bound
    lon_e_edges_xe = np.append(lon_e_edges, lon_e_edges[-1] + 1/80)
    lat_e_edges_xe = np.append(lat_e_edges, lat_e_edges[-1] + 1/120)
    
    #lat_e_edges = np.concatenate([lat_in - dlat_e, [lat_in.max() + dlat_e]])
    #lon_e_edges = np.concatenate([lon_in, [lon_in.max() + dlon_e]])
    #print(f" 10min eagrid nc's lon edges {lon_in[:10]}")
    #print(f" first  lon_e_edges, {lon_e_edges[:5]}")
    #print(f" end 5 of lon_e_edges, {lon_e_edges[-5:]}")
    #print(f"len of lot_e_edges {len(lon_e_edges)}")
    #print('')
    #print(f" first 5 of lat_e_edges, {lat_e_edges[:5]}")
    #print(f" end 5 of lat_e_edges, {lat_e_edges[-5:]}")
   # == Put emission in (point data into 2d array) ==
    Lon_in, Lat_in = np.meshgrid(lon_e_edges, lat_e_edges)
    emission_grid = np.full(Lon_in.shape, np.nan)
    for lon, lat, val in zip(lon_in, lat_in, emission_in):
        i = np.argmin(np.abs(lat_e_edges - lat))
        # print(lat_array[i]- lat)   < = This is all 0, means lat_array made in def get_latlon_array is align with nc grid
        j = np.argmin(np.abs(lon_e_edges - lon))
    #     if abs(lat_array[i] - lat) <= lat_half and abs(lon_array[j] - lon) <= lon_half:
        emission_grid[i, j] = val
        #print(val)
   # == =========
    #print(emission_grid.shape)
    #plt.imshow(emission_grid)
    #plt.show()

    # make the edge lon and lat of target grid (high reso but align eith cams)
    # to calculate the overlap between eagrid emission grid
    #print(f" len of eagrid_lon_array {len(eagrid_lon_array)}")
    #print(f" len of eagrid_lat_array {len(eagrid_lat_array)}")
    lat_t_edges = centers_to_edges(eagrid_lat_array)
    lon_t_edges = centers_to_edges(eagrid_lon_array)
    cams_lat_array_edges = centers_to_edges(cams_lat_array)
    cams_lon_array_edges = centers_to_edges(cams_lon_array)
    #print(f"first of lon e and t  {lon_e_edges[0], lon_t_edges[0]}")
    #print(f"end   of lon e and t {lon_e_edges[-1], lon_t_edges[-1]}")

    #print(f"first of lat e and t  {lat_e_edges[0], lat_t_edges[0]}")
    #print(f"end   of lat e and t {lat_e_edges[-1], lat_t_edges[-1]}")

   # print(f"len of lat_t_edges {len(lat_t_edges)}")
   # print(f"len of lon_t_edges {len(lon_t_edges)}")
    # grid_in =  {'lon': lon_e_center, 'lat': lat_e_center}
    # grid_out = {'lon': eagrid_lon_array, 'lat': eagrid_lat_array}

    #regridder = xe.Regridder(grid_in,grid_out, 'conservative')
    # print(lon_e_center.shape)
    # print(lat_e_center.shape)
    # print(lon_e_edges.shape)
    # print(lat_e_edges.shape)
    # print(eagrid_lon_array.shape)
    # print(eagrid_lat_array.shape)
    # print(lon_t_edges.shape)
    # print(lat_t_edges.shape)
    # print(cams_lon_array.shape)
    # print(cams_lat_array.shape)
    # print(cams_lon_array_edges.shape)
    # print(cams_lat_array_edges.shape)
    
    # print(emission_grid.shape)
    # print(cams_emission.shape)
    # For emission grid

    grid_in = {"lon": lon_e_center, 
               "lat": lat_e_center,
               "lon_b": lon_e_edges_xe,
               "lat_b": lat_e_edges_xe}

    grid_out = {"lon": eagrid_lon_array, 
                  "lat": eagrid_lat_array,
                  "lon_b": lon_t_edges,
                  "lat_b": lat_t_edges}
    #grid_in_cams = {"lon": cams_lon_array, "lat": cams_lat_array}
    regridder = xe.Regridder(grid_in, grid_out, 'conservative')
    value_grid = regridder(emission_grid)

    # For CAMS grid
    grid_in_cams ={"lon": cams_lon_array, 
                   "lat": cams_lat_array,
                   "lon_b": cams_lon_array_edges,
                   "lat_b": cams_lat_array_edges
    }
    regridder_cams = xe.Regridder(grid_in_cams, grid_out,'conservative')
    fine_cams_emission = regridder_cams(cams_emission)
    print("cams before :", np.nansum(cams_emission))
    print("cams after :", np.nansum(fine_cams_emission)/ 100)
    print('')
    print("xe eagrid Before:", np.nansum(emission_grid))
    print("xe eagrid After: ", np.nansum(value_grid)* 24 /25)

    #plt.imshow(value_grid)
    #plt.show()

    return lon_e_edges, lat_e_edges, emission_grid, eagrid_lon_array, eagrid_lat_array, value_grid, fine_cams_emission

    # they are ok 
    # print("lat edges:", lat_t_edges[:5], "...", lat_t_edges[-5:])
    # print("lon edges:", lon_t_edges[:5], "...", lon_t_edges[-5:])
    # print("target lat centers:", eagrid_lat_array[:5], eagrid_lat_array[-5:])
    # print("target lon centers:", eagrid_lon_array[:5], eagrid_lon_array[-5:])
    return eagrid_lon_array, eagrid_lat_array, value_grid

# %%
def eagrid_make2(cams_lon_array, cams_lat_array, k, sector = "All_sources", source = 'NOx'):
    # = make downscaled grid made from original cams grid
    dlon = np.abs(cams_lon_array[1] - cams_lon_array[0])
    dlat = np.abs(cams_lat_array[1] - cams_lat_array[0])

    # build fine grid covering the 5 CAMS cells
    lon_min = cams_lon_array[0] - dlon / 2
    lon_max = cams_lon_array[-1] + dlon / 2
    lat_min = cams_lat_array[0] - dlat / 2
    lat_max = cams_lat_array[-1] + dlat / 2

    fine_dlon = dlon / k
    fine_dlat = dlat / k

    # The lat lon is the center of grid
    # eagrid_lon_array = np.round(np.arange(lon_min + fine_dlon/2 , lon_max + 0.5 * fine_dlon , fine_dlon), 4)
    # eagrid_lat_array =np.round(np.arange(lat_min + fine_dlat/2, lat_max + 0.5 * fine_dlat , fine_dlat),4)

    
    eagrid_lon_array = np.round(np.linspace(lon_min + fine_dlon/2, lon_max - fine_dlon/2, 5 * k), 4)
    eagrid_lat_array = np.round(np.linspace(lat_min + fine_dlat/2, lat_max - fine_dlat/2, 5 * k), 4)
    
    Lon, Lat = np.meshgrid(eagrid_lon_array, eagrid_lat_array)
    value_grid = np.zeros(Lon.shape, dtype = float)  # data will be stored 
    area_grid  = np.zeros_like(value_grid) # area of overlap will be stored

    # print(f"cams_lat_array {len(cams_lat_array), cams_lat_array}")
    # print(f" first eagrid_lat_arra {eagrid_lat_array[0]}")
    # print(f" end eagrid_lat_array {eagrid_lat_array[-5:]}")
    # print(f" len of eagrid_lon_array {len(eagrid_lon_array)}")
    # print(f"first of eagrid_lon_array {eagrid_lon_array[:5]}")

    # == From here eagrid data is read == 
    sec_idx = int(ds.sector.to_index().get_loc(sector))
    src_idx = int(ds.source.to_index().get_loc(source))

    lat_e = ds["lat"].values
    lon_e = ds["lon"].values
    emission = ds["Emission"][sec_idx, src_idx, :].values

    # == mask ====
    # get a range from lat_array and lon_array
    margin = 0.05
    lat_min, lat_max = eagrid_lat_array[0], eagrid_lat_array[-1]
    lon_min, lon_max = eagrid_lon_array[0], eagrid_lon_array[-1]
    mask = (lat_e >= lat_min - margin) & (lat_e <= lat_max + margin) & \
           (lon_e >= lon_min - margin) & (lon_e <= lon_max + margin)
    # extract # lat_in, lon_in are left bottom
    lat_in = lat_e[mask]
    lon_in = lon_e[mask]

    emission_in = emission[mask]

    # # only keep points with no multiple values
    # coords = np.column_stack((lon_in,lat_in))
    # _, unique_idx = np.unique(coords, axis=0, return_index=True)

    # lon_in = lon_in[unique_idx]
    # lat_in = lat_in[unique_idx]
    # emission_in = emission_in[unique_idx]

    # TODO currently hard-corded, needs to be revisited
    #dlat_e = 1/240
    #dlon_e = 1/160
    lon_e_edges , lat_e_edges = get_latlon_array([lat_min , lat_max ],[lon_min , lon_max])
    #lat_e_edges = np.concatenate([lat_in - dlat_e, [lat_in.max() + dlat_e]])
    #lon_e_edges = np.concatenate([lon_in, [lon_in.max() + dlon_e]])
    #print(f" 10min eagrid nc's lon edges {lon_in[:10]}")
    #print(f" first  lon_e_edges, {lon_e_edges[:5]}")
    #print(f" end 5 of lon_e_edges, {lon_e_edges[-5:]}")
    #print(f"len of lot_e_edges {len(lon_e_edges)}")
    #print('')
    #print(f" first 5 of lat_e_edges, {lat_e_edges[:5]}")
    #print(f" end 5 of lat_e_edges, {lat_e_edges[-5:]}")
   # == Put emission in (point data into 2d array) ==
    Lon_in, Lat_in = np.meshgrid(lon_e_edges, lat_e_edges)
    emission_grid = np.full(Lon_in.shape, np.nan)
    for lon, lat, val in zip(lon_in, lat_in, emission_in):
        i = np.argmin(np.abs(lat_e_edges - lat))
        # print(lat_array[i]- lat)   < = This is all 0, means lat_array made in def get_latlon_array is align with nc grid
        j = np.argmin(np.abs(lon_e_edges - lon))
    #     if abs(lat_array[i] - lat) <= lat_half and abs(lon_array[j] - lon) <= lon_half:
        emission_grid[i, j] = val
        #print(val)
   # == =========
    #print(emission_grid.shape)
    #plt.imshow(emission_grid)
    #plt.show()

    # make the edge lon and lat of target grid (high reso but align eith cams)
    # to calculate the overlap between eagrid emission grid
    #print(f" len of eagrid_lon_array {len(eagrid_lon_array)}")
    #print(f" len of eagrid_lat_array {len(eagrid_lat_array)}")
    lat_t_edges = centers_to_edges(eagrid_lat_array)
    lon_t_edges = centers_to_edges(eagrid_lon_array)
    print(f"first of lon e and t  {lon_e_edges[0], lon_t_edges[0]}")
    print(f"end   of lon e and t {lon_e_edges[-1], lon_t_edges[-1]}")

    print(f"first of lat e and t  {lat_e_edges[0], lat_t_edges[0]}")
    print(f"end   of lat e and t {lat_e_edges[-1], lat_t_edges[-1]}")

   # print(f"len of lat_t_edges {len(lat_t_edges)}")
   # print(f"len of lon_t_edges {len(lon_t_edges)}")


    #print(f"edge and center {lon_t_edges, eagrid_lon_array}")
    # loop for all emisson grid
    for i in range(len(lat_e_edges)-1):
        for j in range(len(lon_e_edges)-1):
            # boundary from emission data
            e_lat0 = lat_e_edges[i]
            e_lat1 = lat_e_edges[i +1]
            e_lon0 = lon_e_edges[j]
            e_lon1 = lon_e_edges[j+1]
            
            emis = emission_grid[i, j]
            if np.isnan(emis):
                continue
                
            # index of target gird where lat lon of emission includes
            ti0 = np.searchsorted(lat_t_edges, e_lat0) - 1
            ti1 = np.searchsorted(lat_t_edges, e_lat1) 
            tj0 = np.searchsorted(lon_t_edges, e_lon0) - 1
            tj1 = np.searchsorted(lon_t_edges, e_lon1) 

            #print(f"tj0, tj1 {tj0,tj1}")
            
            # for all emission grids which is overlap to a certain target grid

            
            for ti in range(ti0, ti1):
                for tj in range(tj0, tj1):
                    

                    # if something wrong, skip calculation 
                    
                    if ti < 0 or tj < 0 or ti >= value_grid.shape[0] or tj >= value_grid.shape[1]:
                        print("skip the ti and tj loop")
                    
                        continue
                    # lon lat of target grid    
                    t_lat0 = lat_t_edges[ti]
                    t_lat1 = lat_t_edges[ti+1]
                    t_lon0 = lon_t_edges[tj]
                    t_lon1 = lon_t_edges[tj+1]   
                
                    
                    overlap_lon = min(e_lon1, t_lon1) - max(e_lon0, t_lon0)
                    
                    if overlap_lon <= 1e-20:
                        #print("overlap_lon <= 0")
                        continue
                        
                    overlap_lat = min(e_lat1, t_lat1) - max(e_lat0, t_lat0)
                    
                    if overlap_lat <= 1e-20:
                        #print("overlap_lat <=0")
                        continue

                    
                    # == original version ====
                    # put the eission data into value grid 
                    overlap_area = overlap_lon * overlap_lat
                    # emission area and fraction
                    e_area = (e_lat1 - e_lat0) * (e_lon1 - e_lon0)             
                    frac = overlap_area / e_area
                    
                    #print(f" frac {frac}")  # This is not 0
                    value_grid[ti, tj] += emis * frac
                    area_grid[ti, tj]  += overlap_area
                    # # ==-==================
            #print(" ")
    print("original Before:", np.nansum(emission_grid))
    print("Original After: ", np.nansum(value_grid))

    #plt.imshow(value_grid)
    #plt.show()

    return lon_e_edges, lat_e_edges, emission_grid, eagrid_lon_array, eagrid_lat_array, value_grid

    # they are ok 
    # print("lat edges:", lat_t_edges[:5], "...", lat_t_edges[-5:])
    # print("lon edges:", lon_t_edges[:5], "...", lon_t_edges[-5:])
    # print("target lat centers:", eagrid_lat_array[:5], eagrid_lat_array[-5:])
    # print("target lon centers:", eagrid_lon_array[:5], eagrid_lon_array[-5:])
    return eagrid_lon_array, eagrid_lat_array, value_grid

# %%
cams_pix = 5
cams_lon_array, cams_lat_array, cams_emission= cams_make(135.725, 35.050,  camsds, cams_pix)

# %%
lon_e_edges, lat_e_edges, emission_grid, eagrid_lon_array, eagrid_lat_array, value_grid, fine_cams_emission = eagrid_make_xesmf(cams_lon_array,cams_lat_array, cams_emission,10,  sector = "All_sources", source = 'NOx')

# cams compare 
fig, axes = plt.subplots(1, 2, figsize=(14, 7))  # 横並び2列、各7x7相当

# ------------------- before -------------------
ax = axes[0]
cmap = cm.roma_r
norm = mcolors.Normalize(vmin=2.5, vmax=6.5)

sc = ax.pcolormesh(cams_lon_array, cams_lat_array, np.log10(cams_emission),
                   cmap=cmap, norm=norm,
                   edgecolors='lightgray', linewidth=0.2)
ax.set(xlim=[cams_lon_array[0], cams_lon_array[-1]], ylim=[cams_lat_array[0], cams_lat_array[-1]])
cb = plt.colorbar(sc, ax=ax, shrink=0.7, aspect=20, fraction=0.046)
cb.ax.tick_params(labelsize=7)
cb.set_label('before', fontsize=7)
ax.set_title('Before', fontsize=10)

# ------------------- after -------------------
ax = axes[1]
sc = ax.pcolormesh(eagrid_lon_array, eagrid_lat_array, np.log10(fine_cams_emission),
                   cmap=cmap, norm=norm,
                   edgecolors='lightgray', linewidth=0.2)
ax.set(xlim=[eagrid_lon_array[0], eagrid_lon_array[-1]], ylim=[eagrid_lat_array[0], eagrid_lat_array[-1]])
cb = plt.colorbar(sc, ax=ax, shrink=0.7, aspect=20, fraction=0.046)
cb.ax.tick_params(labelsize=7)
cb.set_label('after', fontsize=7)
ax.set_title('After', fontsize=10)
plt.title('CAMS')
plt.tight_layout()
plt.show()



# == EAGrids before and after regridding =======
fig, axes = plt.subplots(1, 2, figsize=(14, 7))  # 横並び2列、各7x7相当

# ------------------- before -------------------
ax = axes[0]
cmap = cm.roma_r
norm = mcolors.Normalize(vmin=2.5, vmax=6.5)

sc = ax.pcolormesh(lon_e_edges, lat_e_edges, np.log10(emission_grid),
                   cmap=cmap, norm=norm,
                   edgecolors='lightgray', linewidth=0.2)
ax.set(xlim=[lon_e_edges[0], lon_e_edges[-1]], ylim=[lat_e_edges[0], lat_e_edges[-1]])
cb = plt.colorbar(sc, ax=ax, shrink=0.7, aspect=20, fraction=0.046)
cb.ax.tick_params(labelsize=7)
cb.set_label('before', fontsize=7)
ax.set_title('Before', fontsize=10)

# ------------------- after -------------------
ax = axes[1]
sc = ax.pcolormesh(eagrid_lon_array, eagrid_lat_array, np.log10(value_grid),
                   cmap=cmap, norm=norm,
                   edgecolors='lightgray', linewidth=0.2)
ax.set(xlim=[eagrid_lon_array[0], eagrid_lon_array[-1]], ylim=[eagrid_lat_array[0], eagrid_lat_array[-1]])
cb = plt.colorbar(sc, ax=ax, shrink=0.7, aspect=20, fraction=0.046)
cb.ax.tick_params(labelsize=7)
cb.set_label('after', fontsize=7)
ax.set_title('After', fontsize=10)

plt.title('EAGrid')
plt.tight_layout()
plt.show()
# Out:
# cams before : 156442.45
# cams after : 156438.86
#
# xe eagrid Before: 33588002.45573038
# xe eagrid After:  32670144.932389747
# /var/folders/b2/4zv441n11_s6ww9psppcn0s80000gn/T/ipykernel_53760/1320105919.py:44: RuntimeWarning: divide by zero encountered in log10
#   sc = ax.pcolormesh(lon_e_edges, lat_e_edges, np.log10(emission_grid),
# /var/folders/b2/4zv441n11_s6ww9psppcn0s80000gn/T/ipykernel_53760/1320105919.py:55: RuntimeWarning: divide by zero encountered in log10
#   sc = ax.pcolormesh(eagrid_lon_array, eagrid_lat_array, np.log10(value_grid),

# %%
def make_testdata(camsds, ds, cams_pix,  scale_factor , sector = "All_sources", source = 'NOx'):
    # == eagrid data read ===
    sec_idx = int(ds.sector.to_index().get_loc(sector))
    src_idx = int(ds.source.to_index().get_loc(source))

    lat_e = ds["lat"].values
    lon_e = ds["lon"].values
    emission = ds["Emission"][sec_idx, src_idx, :].values

    #lat_e_uni = np.unique(lat_e)
    #lon_e_uni = np.unique(lon_e)
    #emission_2d = emission.reshape(len(lat_e_uni),len(lon_e_uni))
    
    min_lon = np.min(lon_e)
    max_lon = np.max(lon_e)
    min_lat = np.min(lat_e)
    max_lat = np.max(lat_e)
    
    # ==========================
    lon_array = np.arange(min_lon , max_lon , 0.3)  #  cams grid is 0.1 degree
    lat_array = np.arange(min_lat , max_lat , 0.3)

    print(f"before removed {len(lon_array) , len(lat_array)}")

    dataset_lon_array = []   # THE array for the center lon lat of image, which has almost all data (less nan)
    dataset_lat_array = []
    
    for lon in lon_array:
        for lat in lat_array:
            half_size = cams_pix * 0.1 / 2  # as 5x5 of cams pixel, the hald degree is 0.25
            dlat = np.abs(lat_e - lat)
            dlon = np.abs(lon_e - lon)
            
            mask = (dlat <= half_size) & (dlon <= half_size)
         
            #print(f"len of mask (True count): {np.sum(mask)}")

            sub_points = emission[mask]
            total = sub_points.size
            if total == 0:
                continue
            if np.nansum(sub_points) < 100:
                continue

            
            invalid_mask = np.isnan(sub_points) | (sub_points == 0)
            ratio_invalid = invalid_mask.sum() / total

            if ratio_invalid < 0.5:
                dataset_lon_array.append(lon)
                dataset_lat_array.append(lat)
       
                
    print(f"len of LON LAT {len(dataset_lon_array), len(dataset_lat_array)}")            

    num_dataset = len(dataset_lon_array)
    cams_dataset = np.full([num_dataset, 5,5], np.nan)
    eagrid_dataset = np.full([num_dataset, 50, 50], np.nan)   # 3d (num of dataset, 50, 50)
    diff_array = np.zeros(num_dataset)
    diff_array_xe = np.zeros(num_dataset) 
    for i, (lon, lat) in enumerate(zip(dataset_lon_array, dataset_lat_array)):
        print(f"{lon:.3f}, {lat:.3f}")
        cams_lon_array, cams_lat_array, cams_emission = cams_make(lon, lat,  camsds, cams_pix)
        lon_e_edges_xe, lat_e_edges_xe, emission_grid_xe, eagrid_lon_array_xe, eagrid_lat_array_xe, value_grid_xe, fine_cams_emission_xe = eagrid_make_xesmf(cams_lon_array,cams_lat_array,cams_emission, 10,  sector = "All_sources", source = 'NOx')
        lon_e_edges, lat_e_edges, emission_grid, eagrid_lon_array, eagrid_lat_array, value_grid = eagrid_make2(cams_lon_array,cams_lat_array, 10,  sector = "All_sources", source = 'NOx')
        cams_dataset[i] = cams_emission
        eagrid_dataset[i] = value_grid
        rsdiff_xe = np.sqrt((np.nansum(value_grid_xe) - np.nansum(emission_grid_xe))**2) / np.nansum(emission_grid_xe)
        rsdiff = np.sqrt((np.nansum(value_grid) - np.nansum(emission_grid))**2) / np.nansum(emission_grid)

        diff_array[i] = rsdiff
        diff_array_xe[i] = rsdiff_xe

        

    
        
    return cams_dataset, eagrid_dataset, diff_array, diff_array_xe

# %%
cams_dataset, eagrid_dataset, diff_array, diff_array_xe = make_testdata(camsds,ds, 5, 10, "All_sources", "NOx")
# Out:
# before removed (104, 72)
# len of LON LAT (681, 681)
# 122.825, 24.250
# cams before : 10860.709
# cams after : 10860.46
#
# xe eagrid Before: 137997.4779047966
# xe eagrid After:  113728.67808496093
# first of lon e and t  (122.6125, 122.60000000000001)
# end   of lon e and t (123.1, 123.1)
# first of lat e and t  (24.00833, 24.0)
# end   of lat e and t (24.5, 24.5)
# original Before: 137997.4779047966
# Original After:  137988.5655016899
# 122.825, 24.550
# cams before : 13918.42
# cams after : 13918.1
#
# xe eagrid Before: 137997.4779047966
# xe eagrid After:  113728.67808496093
# first of lon e and t  (122.6125, 122.60000000000001)
# end   of lon e and t (123.1, 123.1)
# first of lat e and t  (24.30833, 24.299999999999997)
# end   of lat e and t (24.8, 24.800000000000004)
# original Before: 137997.4779047966
# Original After:  137988.5655016899
# 123.125, 24.250
# cams before : 20360.844
# cams after : 20360.5175
#
# xe eagrid Before: 137488.65006017685
# xe eagrid After:  113728.67808496093
# first of lon e and t  (122.9125, 122.9)
# end   of lon e and t (123.4, 123.39999999999999)
# first of lat e and t  (24.00833, 24.0)
# end   of lat e and t (24.5, 24.5)
# original Before: 137488.65006017685
# Original After:  137488.65006017685
# 123.125, 24.550
# cams before : 12879.393
# cams after : 12879.16125
#
# xe eagrid Before: 137488.65006017685
# xe eagrid After:  113728.67808496093
# first of lon e and t  (122.9125, 122.9)
# end   of lon e and t (123.4, 123.39999999999999)
# first of lat e and t  (24.30833, 24.299999999999997)
# end   of lat e and t (24.8, 24.800000000000004)
# original Before: 137488.65006017685
# Original After:  137488.65006017685
# 123.725, 23.950
# cams before : 461.39426
# cams after : 461.3919921875
#
# xe eagrid Before: 7682.286982178688
# cams after : 2866.3784375
#
# xe eagrid Before: 66002.44223022461
# xe eagrid After:  52590.451221182346
# first of lon e and t  (124.4125, 124.4)
# end   of lon e and t (124.9, 124.89999999999999)
# first of lat e and t  (24.60833, 24.6)
# end   of lat e and t (25.1, 25.099999999999998)
# original Before: 66002.44223022461
# Original After:  66002.44223022461
# 124.925, 24.550
# cams before : 861.9827
# cams after : 861.97984375
#
# xe eagrid Before: 18786.30156326294
# xe eagrid After:  4316.18495836452
# first of lon e and t  (124.7125, 124.69999999999999)
# end   of lon e and t (125.2, 125.19999999999999)
# first of lat e and t  (24.30833, 24.299999999999997)
# end   of lat e and t (24.8, 24.800000000000004)
# original Before: 18786.30156326294
# Original After:  7319.358600616455
# 124.925, 24.850
# cams before : 2018.1724
# cams after : 2018.1346875
#
# xe eagrid Before: 81578.70246982574
# xe eagrid After:  58553.794440658494
# first of lon e and t  (124.7125, 124.69999999999999)
# end   of lon e and t (125.2, 125.19999999999999)
# first of lat e and t  (24.60833, 24.6)
# end   of lat e and t (25.1, 25.099999999999998)
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# original Before: 81578.70246982574
# Original After:  67139.74538134663
# 125.225, 24.550
# cams before : 2824.2222
# cams after : 2823.995
#
# xe eagrid Before: 534212.9747362137
# xe eagrid After:  499860.68907461927
# first of lon e and t  (125.0125, 125.0)
# end   of lon e and t (125.5, 125.5)
# first of lat e and t  (24.30833, 24.299999999999997)
# end   of lat e and t (24.8, 24.800000000000004)
# original Before: 534212.9747362137
# Original After:  519471.0821151734
# 125.225, 24.850
# cams before : 5160.2544
# cams after : 5160.1778125
#
# xe eagrid Before: 2480422.254507065
# xe eagrid After:  1733349.6708801847
# first of lon e and t  (125.0125, 125.0)
# end   of lon e and t (125.5, 125.5)
# first of lat e and t  (24.60833, 24.6)
# end   of lat e and t (25.1, 25.099999999999998)
# original Before: 2480422.254507065
# Original After:  2480422.2545070644
# 125.225, 25.150
# cams before : 1711.4146
# cams after : 1711.3728125
#
# xe eagrid Before: 8336.531826019287
# xe eagrid After:  3617.1015652723586
# first of lon e and t  (125.0125, 125.0)
# end   of lon e and t (125.5, 125.5)
# first of lat e and t  (24.90833, 24.900000000000002)
# end   of lat e and t (25.4, 25.4)
# original Before: 8336.531826019287
# Original After:  8336.531826019287
# 125.525, 24.550
# cams before : 3883.6628
# cams after : 3883.491875
#
# xe eagrid Before: 195931.16937446594
# xe eagrid After:  185945.48719120197
# first of lon e and t  (125.3125, 125.30000000000001)
# end   of lon e and t (125.8, 125.80000000000001)
# first of lat e and t  (24.30833, 24.299999999999997)
# end   of lat e and t (24.8, 24.800000000000004)
# original Before: 195931.16937446594
# Original After:  191214.97875404358
# 125.525, 24.850
# cams before : 3240.6143
# cams after : 3240.49
#
# xe eagrid Before: 220157.25835704803
# xe eagrid After:  200263.58091655042
# first of lon e and t  (125.3125, 125.30000000000001)
# end   of lon e and t (125.8, 125.80000000000001)
# first of lat e and t  (24.60833, 24.6)
# end   of lat e and t (25.1, 25.099999999999998)
# original Before: 220157.25835704803
# Original After:  220157.25835704803
# Original After:  32002.730522155758
# 127.325, 26.650
# cams before : 1678.0852
# cams after : 1678.08890625
#
# xe eagrid Before: 30785.516521453857
# xe eagrid After:  28967.46498605584
# first of lon e and t  (127.1125, 127.10000000000001)
# end   of lon e and t (127.6, 127.6)
# first of lat e and t  (26.40833, 26.400000000000002)
# end   of lat e and t (26.9, 26.9)
# original Before: 30785.516521453857
# Original After:  30785.516521453854
# 127.625, 26.050
# cams before : 43125.89
# cams after : 43124.76
#
# xe eagrid Before: 9123992.56171316
# xe eagrid After:  8370316.281960078
# first of lon e and t  (127.4125, 127.4)
# end   of lon e and t (127.9, 127.89999999999999)
# first of lat e and t  (25.80833, 25.799999999999997)
# end   of lat e and t (26.3, 26.300000000000004)
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# original Before: 9123992.56171316
# Original After:  8894999.064858614
# 127.625, 26.350
# cams before : 114504.09
# cams after : 114501.27
#
# xe eagrid Before: 17642610.414984047
# xe eagrid After:  16063784.616115842
# first of lon e and t  (127.4125, 127.4)
# end   of lon e and t (127.9, 127.89999999999999)
# first of lat e and t  (26.10833, 26.1)
# end   of lat e and t (26.6, 26.599999999999998)
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# original Before: 17642610.414984047
# Original After:  17562253.77748913
# 127.625, 26.650
# cams before : 38403.38
# cams after : 38401.0825
#
# xe eagrid Before: 5104956.954840422
# xe eagrid After:  4862149.132230222
# first of lon e and t  (127.4125, 127.4)
# end   of lon e and t (127.9, 127.89999999999999)
# first of lat e and t  (26.40833, 26.400000000000002)
# end   of lat e and t (26.9, 26.9)
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# original Before: 5104956.954840422
# Original After:  5058093.051928154
# 127.625, 26.950
# cams before : 4473.3564
# cams after : 4473.2596875
#
# xe eagrid Before: 52100.02703380585
# xe eagrid After:  34249.047048140645
# first of lon e and t  (127.4125, 127.4)
# end   of lon e and t (127.9, 127.89999999999999)
# first of lat e and t  (26.70833, 26.699999999999996)
# end   of lat e and t (27.2, 27.200000000000003)
# skip the ti and tj loop
# skip the ti and tj loop
# original Before: 52100.02703380585
# Original After:  38203.802860259864
# 127.925, 26.050
# cams before : 35939.19
# cams after : 35938.135
#
# xe eagrid Before: 4860153.60152182
# xe eagrid After:  3914173.2361994595
# first of lon e and t  (127.7125, 127.69999999999999)
# end   of lon e and t (128.2, 128.2)
# first of lat e and t  (25.80833, 25.799999999999997)
# end   of lat e and t (26.3, 26.300000000000004)
# original Before: 4860153.60152182
# Original After:  3978056.478169769
# 127.925, 26.350
# cams before : 111344.195
# cams after : 111339.24
#
# xe eagrid Before: 14294232.358294874
# xe eagrid After:  13070797.05703411
# first of lon e and t  (127.7125, 127.69999999999999)
# end   of lon e and t (128.2, 128.2)
# first of lat e and t  (26.10833, 26.1)
# end   of lat e and t (26.6, 26.599999999999998)
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# original Before: 14294232.358294874
# Original After:  14238754.12470948
# 127.925, 26.650
# cams before : 80098.85
# cams after : 80089.47
#
# xe eagrid Before: 7301158.304661214
# xe eagrid After:  6962928.048850204
# first of lon e and t  (127.7125, 127.69999999999999)
# end   of lon e and t (128.2, 128.2)
# first of lat e and t  (26.40833, 26.400000000000002)
# end   of lat e and t (26.9, 26.9)
# original Before: 7301158.304661214
# Original After:  7292648.329564512
# 127.925, 26.950
# cams before : 41563.746
# cams after : 41557.4925
#
# xe eagrid Before: 261408.1594247818
# xe eagrid After:  94155.1735147009
# first of lon e and t  (127.7125, 127.69999999999999)
# end   of lon e and t (128.2, 128.2)
# first of lat e and t  (26.70833, 26.699999999999996)
# end   of lat e and t (27.2, 27.200000000000003)
# original Before: 261408.1594247818
# Original After:  257956.24411773682
# 127.925, 27.250
# cams before : 4262.1777
# cams after : 4261.991875
#
# xe eagrid Before: 14863.898891448975
# xe eagrid After:  10537.69994351934
# first of lon e and t  (127.7125, 127.69999999999999)
# end   of lon e and t (128.2, 128.2)
# first of lat e and t  (27.00833, 27.0)
# end   of lat e and t (27.5, 27.5)
# original Before: 14863.898891448975
# Original After:  14863.898891448975
# 128.225, 26.350
# cams before : 8316.864
# cams after : 8316.53
#
# xe eagrid Before: 77297.09801465273
# xe eagrid After:  42243.28401620948
# first of lon e and t  (128.0125, 128.0)
# end   of lon e and t (128.5, 128.5)
# first of lat e and t  (26.10833, 26.1)
# end   of lat e and t (26.6, 26.599999999999998)
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# original Before: 77297.09801465273
# Original After:  54896.01575833447
# 128.225, 26.650
# cams before : 42811.62
# cams after : 42807.615
#
# xe eagrid Before: 538278.3764973283
# xe eagrid After:  474924.39925579383
# first of lon e and t  (128.0125, 128.0)
# end   of lon e and t (128.5, 128.5)
# first of lat e and t  (26.40833, 26.400000000000002)
# end   of lat e and t (26.9, 26.9)
# original Before: 538278.3764973283
# Original After:  538278.3764973284
# 128.225, 26.950
# cams before : 40148.027
# cams after : 40144.4225
#
# xe eagrid Before: 138126.7997457981
# xe eagrid After:  96454.9387231865
# first of lon e and t  (128.0125, 128.0)
# end   of lon e and t (128.5, 128.5)
# first of lat e and t  (26.70833, 26.699999999999996)
# end   of lat e and t (27.2, 27.200000000000003)
# original Before: 138126.7997457981
# Original After:  138126.7997457981
# 128.225, 27.250
# cams before : 4830.161
# cams after : 4829.9553125
#
# xe eagrid Before: 160679.09173202515
# xe eagrid After:  42153.91832320862
# first of lon e and t  (128.0125, 128.0)
# end   of lon e and t (128.5, 128.5)
# first of lat e and t  (27.00833, 27.0)
# end   of lat e and t (27.5, 27.5)
# original Before: 160679.09173202515
# Original After:  59232.69287681579
# 128.525, 26.650
# cams before : 7961.046
# cams after : 7960.76125
#
# xe eagrid Before: 2964.040671825409
# xe eagrid After:  1973.332880052313
# first of lon e and t  (128.3125, 128.3)
# end   of lon e and t (128.8, 128.79999999999998)
# first of lat e and t  (26.40833, 26.400000000000002)
# end   of lat e and t (26.9, 26.9)
# original Before: 2964.040671825409
# Original After:  2964.0406718254094
# 128.525, 26.950
# cams before : 5718.404
# cams after : 5718.25
#
# xe eagrid Before: 59212.976118564606
# xe eagrid After:  42180.16589642966
# first of lon e and t  (128.3125, 128.3)
# end   of lon e and t (128.8, 128.79999999999998)
# first of lat e and t  (26.70833, 26.699999999999996)
# end   of lat e and t (27.2, 27.200000000000003)
# original Before: 59212.976118564606
# Original After:  59212.976118564606

# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# original Before: 697.714408159256
# Original After:  554.0860054492681
# 129.125, 32.650
# cams before : 4554.2983
# cams after : 4554.1846875
#
# xe eagrid Before: 115305.35817567259
# xe eagrid After:  91724.72488104306
# first of lon e and t  (128.9125, 128.9)
# end   of lon e and t (129.4, 129.40000000000003)
# first of lat e and t  (32.40833, 32.400000000000006)
# end   of lat e and t (32.9, 32.900000000000006)
# original Before: 115305.35817567259
# Original After:  108102.05879930407
# 129.125, 32.950
# cams before : 7909.688
# cams after : 7909.515
#
# xe eagrid Before: 334201.9026423991
# xe eagrid After:  316600.96691293194
# first of lon e and t  (128.9125, 128.9)
# end   of lon e and t (129.4, 129.40000000000003)
# first of lat e and t  (32.70833, 32.699999999999996)
# end   of lat e and t (33.2, 33.2)
# original Before: 334201.9026423991
# Original After:  332993.1537872851
# 129.125, 33.250
# cams before : 11432.093
# cams after : 11431.835
#
# xe eagrid Before: 123711.85315288603
# xe eagrid After:  84724.06018818854
# first of lon e and t  (128.9125, 128.9)
# end   of lon e and t (129.4, 129.40000000000003)
# first of lat e and t  (33.00833, 33.0)
# end   of lat e and t (33.5, 33.5)
# original Before: 123711.85315288603
# Original After:  93829.62139047682
# 129.125, 34.150
# cams before : 16666.812
# cams after : 16666.5925
#
# xe eagrid Before: 1511120.204398632
# xe eagrid After:  1491489.9697312089
# first of lon e and t  (128.9125, 128.9)
# end   of lon e and t (129.4, 129.40000000000003)
# first of lat e and t  (33.90833, 33.900000000000006)
# end   of lat e and t (34.4, 34.400000000000006)
# original Before: 1511120.204398632
# Original After:  1505997.6149282455
# 129.125, 34.450
# cams before : 27199.889
# cams after : 27199.39
#
# xe eagrid Before: 1526956.048261419
# xe eagrid After:  1499681.2550043776
# first of lon e and t  (128.9125, 128.9)
# end   of lon e and t (129.4, 129.40000000000003)
# first of lat e and t  (34.20833, 34.199999999999996)
# end   of lat e and t (34.7, 34.7)
# original Before: 1526956.048261419
# Original After:  1517993.0360748768
# 129.125, 34.750
# cams before : 72024.95
# cams after : 72023.89
#
# xe eagrid Before: 93988.0209350586
# xe eagrid After:  81156.42252857768
# first of lon e and t  (128.9125, 128.9)
# end   of lon e and t (129.4, 129.40000000000003)
# first of lat e and t  (34.50833, 34.5)
# end   of lat e and t (35.0, 35.0)
# original Before: 93988.0209350586
# Original After:  84144.70835494994
# 129.425, 28.150
# cams before : 7572.1875
# cams after : 7572.0075
#
# xe eagrid Before: 645317.8179804534
# xe eagrid After:  538920.8328994679
# first of lon e and t  (129.2125, 129.20000000000002)
# end   of lon e and t (129.7, 129.7)
# first of lat e and t  (27.90833, 27.900000000000002)
# end   of lat e and t (28.4, 28.4)
# original Before: 645317.8179804534
# Original After:  632078.8842897862
# 129.425, 28.450
# cams before : 10135.748
# cams after : 10135.528125
#
# xe eagrid Before: 638216.1214328855
# xe eagrid After:  552953.5939739995
# first of lon e and t  (129.2125, 129.20000000000002)
# end   of lon e and t (129.7, 129.7)
# first of lat e and t  (28.20833, 28.199999999999996)
# end   of lat e and t (28.7, 28.700000000000003)
# original Before: 638216.1214328855
# Original After:  625082.8145776838
# 129.425, 28.750
# cams before : 8618.088
# cams after : 8617.7875
#
# xe eagrid Before: 3438.1019580960274
# xe eagrid After:  727.6921274231522
# first of lon e and t  (129.2125, 129.20000000000002)
# end   of lon e and t (129.7, 129.7)
# first of lat e and t  (28.50833, 28.5)
# end   of lat e and t (29.0, 29.0)
# original Before: 3438.1019580960274
# Original After:  3438.1019580960274
# 129.425, 32.650
# cams before : 8841.0205
# cams after : 8840.58625
#
# xe eagrid Before: 613661.6111057401
# xe eagrid After:  372420.37948368257
# first of lon e and t  (129.2125, 129.20000000000002)
# end   of lon e and t (129.7, 129.7)
# first of lat e and t  (32.40833, 32.400000000000006)
# end   of lat e and t (32.9, 32.900000000000006)
# original Before: 613661.6111057401
# Original After:  527358.3183591366
# 129.425, 32.950
# cams before : 87412.586
# cams after : 87398.19
#
# xe eagrid Before: 11065138.283280924
# xe eagrid After:  8671726.723949328
# first of lon e and t  (129.2125, 129.20000000000002)
# end   of lon e and t (129.7, 129.7)
# first of lat e and t  (32.70833, 32.699999999999996)
# end   of lat e and t (33.2, 33.2)
# original Before: 11065138.283280924
# Original After:  10805536.688740268
# 129.425, 33.250
# cams before : 20386.113
# cams after : 20384.8325
#
# xe eagrid Before: 7925224.729981631
# xe eagrid After:  7433320.733004109
# first of lon e and t  (129.2125, 129.20000000000002)
# end   of lon e and t (129.7, 129.7)
# first of lat e and t  (33.00833, 33.0)
# end   of lat e and t (33.5, 33.5)
# original Before: 7925224.729981631
# Original After:  7665925.430732936
# 129.425, 33.550
# cams before : 14721.295
# cams after : 14720.69875
#
# xe eagrid Before: 5871762.231107712
# xe eagrid After:  5774250.2194005065
# first of lon e and t  (129.2125, 129.20000000000002)
# end   of lon e and t (129.7, 129.7)
# first of lat e and t  (33.30833, 33.3)
# end   of lat e and t (33.8, 33.800000000000004)
# original Before: 5871762.231107712
# Original After:  5835922.283269882
# 129.425, 33.850
# cams before : 20107.033
# cams after : 20106.0575
#
# xe eagrid Before: 190525.78665351868
# xe eagrid After:  148953.20396954214
# first of lon e and t  (129.2125, 129.20000000000002)
# end   of lon e and t (129.7, 129.7)
# first of lat e and t  (33.60833, 33.599999999999994)
# end   of lat e and t (34.1, 34.099999999999994)
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# original Before: 190525.78665351868
# Original After:  170206.62933540338
# 129.425, 34.150
# cams before : 19175.975
# cams after : 19175.34375
#
# xe eagrid Before: 1491245.1184444427
# xe eagrid After:  1474757.5458342421
# first of lon e and t  (129.2125, 129.20000000000002)
# end   of lon e and t (129.7, 129.7)
# first of lat e and t  (33.90833, 33.900000000000006)
# end   of lat e and t (34.4, 34.400000000000006)
# original Before: 1491245.1184444427
# Original After:  1487885.635678768
# 129.425, 34.450
# cams before : 7764.878
# cams after : 7764.37625
#
# xe eagrid Before: 1569816.3396899253
# xe eagrid After:  1548602.3525685708
# first of lon e and t  (129.2125, 129.20000000000002)
# end   of lon e and t (129.7, 129.7)
# first of lat e and t  (34.20833, 34.199999999999996)
# end   of lat e and t (34.7, 34.7)
# original Before: 1569816.3396899253

# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# original Before: 531448.9075328708
# Original After:  72227.02964519929
# 129.725, 32.650
# cams before : 27467.52
# cams after : 27465.59
#
# xe eagrid Before: 6846826.06324666
# xe eagrid After:  5808879.908315331
# first of lon e and t  (129.5125, 129.5)
# end   of lon e and t (130.0, 130.0)
# first of lat e and t  (32.40833, 32.400000000000006)
# end   of lat e and t (32.9, 32.900000000000006)
# original Before: 6846826.06324666
# Original After:  6090992.282284431
# 129.725, 32.950
# cams before : 130495.79
# cams after : 130485.44
#
# xe eagrid Before: 24629325.903806508
# xe eagrid After:  20588110.95986633
# first of lon e and t  (129.5125, 129.5)
# end   of lon e and t (130.0, 130.0)
# first of lat e and t  (32.70833, 32.699999999999996)
# end   of lat e and t (33.2, 33.2)
# original Before: 24629325.903806508
# Original After:  24347142.70640832
# 129.725, 33.250
# cams before : 85469.07
# cams after : 85471.42
#
# xe eagrid Before: 14311415.777980123
# xe eagrid After:  13703014.867263801
# first of lon e and t  (129.5125, 129.5)
# end   of lon e and t (130.0, 130.0)
# first of lat e and t  (33.00833, 33.0)
# end   of lat e and t (33.5, 33.5)
# original Before: 14311415.777980123
# Original After:  14097970.378456566
# 129.725, 33.550
# cams before : 68134.25
# cams after : 68137.595
#
# xe eagrid Before: 9012238.43473548
# xe eagrid After:  8736448.982189266
# first of lon e and t  (129.5125, 129.5)
# end   of lon e and t (130.0, 130.0)
# first of lat e and t  (33.30833, 33.3)
# end   of lat e and t (33.8, 33.800000000000004)
# original Before: 9012238.43473548
# Original After:  8887319.823960666
# 129.725, 33.850
# cams before : 21766.348
# cams after : 21765.1925
#
# xe eagrid Before: 1273990.8245360851
# xe eagrid After:  1211680.414813032
# first of lon e and t  (129.5125, 129.5)
# end   of lon e and t (130.0, 130.0)
# first of lat e and t  (33.60833, 33.599999999999994)
# end   of lat e and t (34.1, 34.099999999999994)
# original Before: 1273990.8245360851
# Original After:  1273175.7216107843
# 130.025, 28.150
# cams before : 5636.376
# cams after : 5636.295
#
# xe eagrid Before: 97665.32066440582
# xe eagrid After:  71318.56928136865
# first of lon e and t  (129.8125, 129.8)
# end   of lon e and t (130.3, 130.29999999999998)
# first of lat e and t  (27.90833, 27.900000000000002)
# end   of lat e and t (28.4, 28.4)
# original Before: 97665.32066440582
# Original After:  97665.32066440582
# 130.025, 28.450
# cams before : 4486.3403
# cams after : 4486.3153125
#
# xe eagrid Before: 102588.99607944489
# xe eagrid After:  73501.64802628328
# first of lon e and t  (129.8125, 129.8)
# end   of lon e and t (130.3, 130.29999999999998)
# first of lat e and t  (28.20833, 28.199999999999996)
# end   of lat e and t (28.7, 28.700000000000003)
# original Before: 102588.99607944489
# Original After:  102588.99607944489
# 130.025, 28.750
# cams before : 4166.849
# cams after : 4166.755
#
# xe eagrid Before: 2760.1784057617188
# xe eagrid After:  1496.3834678950254
# first of lon e and t  (129.8125, 129.8)
# end   of lon e and t (130.3, 130.29999999999998)
# first of lat e and t  (28.50833, 28.5)
# end   of lat e and t (29.0, 29.0)
# original Before: 2760.1784057617188
# Original After:  2760.1784057617188
# 130.025, 30.850
# cams before : 14830.354
# cams after : 14829.86125
#
# xe eagrid Before: 10080.04654121399
# xe eagrid After:  7486.475426553928
# first of lon e and t  (129.8125, 129.8)
# end   of lon e and t (130.3, 130.29999999999998)
# first of lat e and t  (30.60833, 30.6)
# end   of lat e and t (31.1, 31.099999999999998)
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# original Before: 10080.04654121399
# Original After:  10080.04654121399
# 130.025, 31.150
# cams before : 16724.855
# cams after : 16724.36125
#
# xe eagrid Before: 313262.510571599
# xe eagrid After:  260529.3627789714
# first of lon e and t  (129.8125, 129.8)
# end   of lon e and t (130.3, 130.29999999999998)
# first of lat e and t  (30.90833, 30.900000000000002)
# end   of lat e and t (31.4, 31.4)
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# original Before: 313262.510571599
# Original After:  273006.14160330367
# 130.025, 31.450
# cams before : 4927.6797
# cams after : 4927.660625
#
# xe eagrid Before: 613601.6356145144
# xe eagrid After:  341025.41275311005
# first of lon e and t  (129.8125, 129.8)
# end   of lon e and t (130.3, 130.29999999999998)
# first of lat e and t  (31.20833, 31.199999999999996)
# end   of lat e and t (31.7, 31.700000000000003)
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# original Before: 613601.6356145144
# Original After:  378251.36877936334
# 130.025, 31.750
# cams before : 90359.8
# cams after : 90354.06
#
# xe eagrid Before: 2460731.74924412
# xe eagrid After:  2154920.5348770306
# first of lon e and t  (129.8125, 129.8)
# end   of lon e and t (130.3, 130.29999999999998)
# first of lat e and t  (31.50833, 31.5)
# end   of lat e and t (32.0, 32.0)
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# ...
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# original Before: 5825396.844938636
# Original After:  5758964.472063415
# 144.125, 43.750
# cams before : 9997.579
# cams after : 9997.41625
#
# xe eagrid Before: 1960175.2269254923
# xe eagrid After:  1851195.0167972113
# first of lon e and t  (143.9125, 143.9)
# end   of lon e and t (144.4, 144.40000000000003)
# first of lat e and t  (43.50833, 43.5)
# end   of lat e and t (44.0, 44.0)
# original Before: 1960175.2269254923
# Original After:  1895990.7679713962
# 144.125, 44.050
# cams before : 8478.558
# cams after : 8478.6525
#
# xe eagrid Before: 2012223.6092011333
# xe eagrid After:  1901266.756877222
# first of lon e and t  (143.9125, 143.9)
# end   of lon e and t (144.4, 144.40000000000003)
# first of lat e and t  (43.80833, 43.8)
# end   of lat e and t (44.3, 44.300000000000004)
# original Before: 2012223.6092011333
# Original After:  1999099.3101059794
# 144.125, 44.350
# cams before : 607.7925
# cams after : 607.8047265625
#
# xe eagrid Before: 80886.54559510946
# xe eagrid After:  58232.66777224124
# first of lon e and t  (143.9125, 143.9)
# end   of lon e and t (144.4, 144.40000000000003)
# first of lat e and t  (44.10833, 44.099999999999994)
# end   of lat e and t (44.6, 44.599999999999994)
# original Before: 80886.54559510946
# Original After:  80886.54559510946
# 144.425, 42.850
# cams before : 18314.928
# cams after : 18313.355
#
# xe eagrid Before: 6193723.310560167
# xe eagrid After:  5709313.478457806
# first of lon e and t  (144.2125, 144.20000000000002)
# end   of lon e and t (144.7, 144.7)
# first of lat e and t  (42.60833, 42.599999999999994)
# end   of lat e and t (43.1, 43.099999999999994)
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# original Before: 6193723.310560167
# Original After:  6169328.846910169
# 144.425, 43.150
# cams before : 22045.09
# cams after : 22043.5125
#
# xe eagrid Before: 6672258.300718248
# xe eagrid After:  6180597.611341275
# first of lon e and t  (144.2125, 144.20000000000002)
# end   of lon e and t (144.7, 144.7)
# first of lat e and t  (42.90833, 42.900000000000006)
# end   of lat e and t (43.4, 43.400000000000006)
# original Before: 6672258.300718248
# Original After:  6642649.632788837
# 144.425, 43.450
# cams before : 6728.7656
# cams after : 6728.46125
#
# xe eagrid Before: 748148.0441393852
# xe eagrid After:  716704.108421025
# first of lon e and t  (144.2125, 144.20000000000002)
# end   of lon e and t (144.7, 144.7)
# first of lat e and t  (43.20833, 43.199999999999996)
# end   of lat e and t (43.7, 43.7)
# original Before: 748148.0441393852
# Original After:  722850.029405117
# 144.425, 43.750
# cams before : 8312.626
# cams after : 8312.356875
#
# xe eagrid Before: 1619096.7940365076
# xe eagrid After:  1520741.5388328528
# first of lon e and t  (144.2125, 144.20000000000002)
# end   of lon e and t (144.7, 144.7)
# first of lat e and t  (43.50833, 43.5)
# end   of lat e and t (44.0, 44.0)
# original Before: 1619096.7940365076
# Original After:  1595783.0551341772
# 144.425, 44.050
# cams before : 5577.912
# cams after : 5577.8975
#
# xe eagrid Before: 1637893.3186392784
# xe eagrid After:  1554605.127516579
# first of lon e and t  (144.2125, 144.20000000000002)
# end   of lon e and t (144.7, 144.7)
# first of lat e and t  (43.80833, 43.8)
# end   of lat e and t (44.3, 44.300000000000004)
# original Before: 1637893.3186392784
# Original After:  1629803.0044312477
# 144.725, 42.850
# cams before : 2780.5833
# cams after : 2780.3896875
#
# xe eagrid Before: 397399.6487492919
# xe eagrid After:  344008.82157027617
# first of lon e and t  (144.5125, 144.5)
# end   of lon e and t (145.0, 145.0)
# first of lat e and t  (42.60833, 42.599999999999994)
# end   of lat e and t (43.1, 43.099999999999994)
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# original Before: 397399.6487492919
# Original After:  388163.76264588634
# 144.725, 43.150
# cams before : 6122.984
# cams after : 6122.68125
#
# xe eagrid Before: 925595.5593501925
# xe eagrid After:  856126.4127648008
# first of lon e and t  (144.5125, 144.5)
# end   of lon e and t (145.0, 145.0)
# first of lat e and t  (42.90833, 42.900000000000006)
# end   of lat e and t (43.4, 43.400000000000006)
# original Before: 925595.5593501925
# Original After:  900296.9862795471
# 144.725, 43.450
# cams before : 8261.07
# cams after : 8260.688125
#
# xe eagrid Before: 1000883.4832286835
# xe eagrid After:  975319.5920489394
# first of lon e and t  (144.5125, 144.5)
# end   of lon e and t (145.0, 145.0)
# first of lat e and t  (43.20833, 43.199999999999996)
# end   of lat e and t (43.7, 43.7)
# original Before: 1000883.4832286835
# Original After:  976228.2757930756
# 144.725, 44.050
# cams before : 2474.6287
# cams after : 2474.59796875
#
# xe eagrid Before: 882099.1916680336
# xe eagrid After:  815384.1604222846
# first of lon e and t  (144.5125, 144.5)
# end   of lon e and t (145.0, 145.0)
# first of lat e and t  (43.80833, 43.8)
# end   of lat e and t (44.3, 44.300000000000004)
# original Before: 882099.1916680336
# Original After:  879932.3279519081
# 145.025, 43.150
# cams before : 5726.68
# cams after : 5726.53125
#
# xe eagrid Before: 702796.8645548895
# xe eagrid After:  638627.3423306037
# first of lon e and t  (144.8125, 144.8)
# end   of lon e and t (145.3, 145.29999999999998)
# first of lat e and t  (42.90833, 42.900000000000006)
# end   of lat e and t (43.4, 43.400000000000006)
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# original Before: 702796.8645548895
# Original After:  685001.188238838
# 145.025, 43.450
# cams before : 22783.004
# cams after : 22780.5275
#
# xe eagrid Before: 1108370.0822771862
# xe eagrid After:  1059999.8907729536
# first of lon e and t  (144.8125, 144.8)
# end   of lon e and t (145.3, 145.29999999999998)
# first of lat e and t  (43.20833, 43.199999999999996)
# end   of lat e and t (43.7, 43.7)
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# original Before: 1108370.0822771862
# Original After:  1092838.5069044617
# 145.025, 43.750
# cams before : 18820.975
# cams after : 18819.8575
#
# xe eagrid Before: 701534.5325319767
# xe eagrid After:  622352.7448428902
# first of lon e and t  (144.8125, 144.8)
# end   of lon e and t (145.3, 145.29999999999998)
# first of lat e and t  (43.50833, 43.5)
# end   of lat e and t (44.0, 44.0)
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# skip the ti and tj loop
# original Before: 701534.5325319767
# Original After:  692828.45876336
# 145.325, 42.850
# cams before : 5786.471
# cams after : 5786.409375
#
# xe eagrid Before: 27893.83685350418
# xe eagrid After:  16894.960558578143
# first of lon e and t  (145.1125, 145.09999999999997)
# end   of lon e and t (145.6, 145.6)
# first of lat e and t  (42.60833, 42.599999999999994)
# end   of lat e and t (43.1, 43.099999999999994)
# skip the ti and tj loop
# skip the ti and tj loop
# original Before: 27893.83685350418
# Original After:  25332.704483509064
# 145.325, 43.150
# cams before : 3597.3657
# cams after : 3597.2709375
#
# xe eagrid Before: 701719.5049298629
# xe eagrid After:  633195.9062049555
# first of lon e and t  (145.1125, 145.09999999999997)
# end   of lon e and t (145.6, 145.6)
# first of lat e and t  (42.90833, 42.900000000000006)
# end   of lat e and t (43.4, 43.400000000000006)
# original Before: 701719.5049298629
# Original After:  696350.610766016
# 145.325, 43.450
# cams before : 18775.713
# cams after : 18774.36125
#
# xe eagrid Before: 799448.994534336
# xe eagrid After:  718224.2882309215
# first of lon e and t  (145.1125, 145.09999999999997)
# end   of lon e and t (145.6, 145.6)
# first of lat e and t  (43.20833, 43.199999999999996)
# end   of lat e and t (43.7, 43.7)
# original Before: 799448.994534336
# Original After:  796071.045063816
# 145.325, 43.750
# cams before : 16032.861
# cams after : 16032.72875
#
# xe eagrid Before: 207143.2918176651
# xe eagrid After:  142700.77145238157
# first of lon e and t  (145.1125, 145.09999999999997)
# end   of lon e and t (145.6, 145.6)
# first of lat e and t  (43.50833, 43.5)
# end   of lat e and t (44.0, 44.0)
# original Before: 207143.2918176651
# Original After:  206059.7107629776
# 145.625, 43.150
# cams before : 4386.1323
# cams after : 4385.99375
#
# xe eagrid Before: 490827.34258755296
# xe eagrid After:  432512.1266512355
# first of lon e and t  (145.4125, 145.4)
# end   of lon e and t (145.9, 145.90000000000003)
# first of lat e and t  (42.90833, 42.900000000000006)
# end   of lat e and t (43.4, 43.400000000000006)
# original Before: 490827.34258755296
# Original After:  490827.34258755296
# 145.625, 43.450
# cams before : 3000.2083
# cams after : 3000.2909375
#
# xe eagrid Before: 480355.7603360042
# xe eagrid After:  425176.9390790375
# first of lon e and t  (145.4125, 145.4)
# end   of lon e and t (145.9, 145.90000000000003)
# first of lat e and t  (43.20833, 43.199999999999996)
# end   of lat e and t (43.7, 43.7)
# original Before: 480355.7603360042
# Original After:  480355.7603360042
# 145.925, 43.150
# cams before : 5794.789
# cams after : 5794.55375
#
# xe eagrid Before: 29855.651690391824
# xe eagrid After:  25727.761162487397
# first of lon e and t  (145.7125, 145.70000000000002)
# end   of lon e and t (146.2, 146.2)
# first of lat e and t  (42.90833, 42.900000000000006)
# end   of lat e and t (43.4, 43.400000000000006)
# original Before: 29855.651690391824
# Original After:  29855.651690391827
# 145.925, 43.450
# cams before : 1089.8218
# cams after : 1089.818125
#
# xe eagrid Before: 29855.651690391824
# xe eagrid After:  25727.761162487404
# first of lon e and t  (145.7125, 145.70000000000002)
# end   of lon e and t (146.2, 146.2)
# first of lat e and t  (43.20833, 43.199999999999996)
# end   of lat e and t (43.7, 43.7)
# original Before: 29855.651690391824
# Original After:  29855.651690391827

# %%
print(diff_array)
print(diff_array_xe)
print(len(diff_array))

plt.plot(diff_array_xe)
plt.plot(diff_array)

plt.show()
a = diff_array[np.isfinite(diff_array)]
b = diff_array_xe[np.isfinite(diff_array_xe)]

vmin = min(a.min(), b.min())
vmax = max(a.max(), b.max())
bins = np.linspace(0, 1, 50)

plt.figure(figsize=(7,5))

plt.hist(a, bins=bins, alpha=0.5, label="Original")
plt.hist(b, bins=bins, alpha=0.5, label="xESMF")

# 平均線
plt.axvline(a.mean(), linestyle="--", linewidth=2, label=f"Original mean = {a.mean():.3f}")
plt.axvline(b.mean(), linestyle="--", linewidth=2, label=f"xESMF mean = {b.mean():.3f}")

plt.xlabel("Relative difference")
plt.ylabel("Probability density")
plt.legend()
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# [6.45838115e-05 6.45838115e-05 0.00000000e+00 0.00000000e+00
#  2.33596836e-02 5.37183255e-01 3.49679205e-02 1.06759181e-01
#  3.55657729e-02 1.20647473e-16 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 6.10388528e-01 1.76994199e-01 2.75955346e-02
#  1.87734684e-16 0.00000000e+00 2.40706501e-02 0.00000000e+00
#  0.00000000e+00 8.30522154e-01 8.16716415e-01 9.55498578e-01
#  0.00000000e+00 1.59617084e-16 1.07578421e-02 1.13677138e-16
#  1.18171764e-16 2.50979487e-02 4.55469092e-03 9.18007798e-03
#  2.66722015e-01 1.81495729e-01 3.88116215e-03 1.16556507e-03
#  1.32050787e-02 0.00000000e+00 2.89804958e-01 2.16273451e-16
#  0.00000000e+00 6.31360296e-01 1.53421427e-16 0.00000000e+00
#  9.01017589e-05 2.90326896e-16 3.85984619e-01 3.61812343e-01
#  2.99140779e-02 5.33188547e-04 1.09391701e-02 0.00000000e+00
#  0.00000000e+00 5.62653681e-01 8.84564882e-04 2.89004054e-03
#  1.68026604e-01 6.80632392e-03 9.65885038e-02 2.05855578e-01
#  6.24715060e-02 3.61682218e-03 2.41547039e-01 3.38992851e-03
