# %% [markdown]
# import numpy as np
# import pandas as pd
# import xarray as xr
# import math

# %%
import numpy as np 
import pandas as pd 
import xarray as xr 
#import math
import matplotlib.pyplot as plt
from cmcrameri import cm
#import cartopy.crs as ccrs
#import cartopy.feature as cfeature
import matplotlib.colors as mcolors
#import matplotlib.image as mpimg
#from scipy.interpolate import RegularGridInterpolator

import xesmf as xe
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/MasterThesis/EAGrid_data/data_create/eagrid_venv/lib/python3.9/site-packages/xesmf/util.py:8
#       7 try:
# ----> 8     import esmpy as ESMF
#       9 except ImportError:
#
# ModuleNotFoundError: No module named 'esmpy'
#
# During handling of the above exception, another exception occurred:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 13
#       9 import matplotlib.colors as mcolors
#      10 #import matplotlib.image as mpimg
#      11 #from scipy.interpolate import RegularGridInterpolator
# ---> 13 import xesmf as xe
#
# File ~/MasterThesis/EAGrid_data/data_create/eagrid_venv/lib/python3.9/site-packages/xesmf/__init__.py:3
#       1 # flake8: noqa
# ----> 3 from . import data, util
#       4 from .frontend import Regridder, SpatialAverager
#       6 try:
#
# File ~/MasterThesis/EAGrid_data/data_create/eagrid_venv/lib/python3.9/site-packages/xesmf/util.py:10
#       8     import esmpy as ESMF
#       9 except ImportError:
# ---> 10     import ESMF
#      12 LON_CF_ATTRS = {'standard_name': 'longitude', 'units': 'degrees_east'}
#      13 LAT_CF_ATTRS = {'standard_name': 'latitude', 'units': 'degrees_north'}
#
# ModuleNotFoundError: No module named 'ESMF'

# %%
ds = xr.open_dataset("Emission_grid_all.nc")

# %%
path2cams = 'CAMS-GLOB-ANT_Glb_0.1x0.1_anthro_nox_v6.2_yearly_2010.nc'
camsds = xr.open_dataset(path2cams)

#camsds = camsds.squeeze().sel(lon=slice(lon_min-1, lon_max+1), lat=slice(lat_min-1, lat_max+1))
print(camsds)
# Out:
# <xarray.Dataset> Size: 363MB
# Dimensions:        (time: 1, lat: 1800, lon: 3600)
# Coordinates:
#   * lat            (lat) float32 7kB -89.95 -89.85 -89.75 ... 89.75 89.85 89.95
#   * lon            (lon) float32 14kB -179.9 -179.9 -179.8 ... 179.8 179.9 179.9
#   * time           (time) datetime64[ns] 8B 2010-01-01
# Data variables: (12/15)
#     agl            (time, lat, lon) float32 26MB ...
#     ags            (time, lat, lon) float32 26MB ...
#     awb            (time, lat, lon) float32 26MB ...
#     com            (time, lat, lon) float32 26MB ...
#     ene            (time, lat, lon) float32 26MB ...
#     fef            (time, lat, lon) float32 26MB ...
#     ...             ...
#     res            (time, lat, lon) float32 26MB ...
#     shp            (time, lat, lon) float32 26MB ...
#     sum            (time, lat, lon) float32 26MB ...
#     swd            (time, lat, lon) float32 26MB ...
#     tnr            (time, lat, lon) float32 26MB ...
#     tro            (time, lat, lon) float32 26MB ...
# Attributes: (12/13)
#     Conventions:        CF-1.6
#     projection:         latlon
#     authors:            A. Soulie and C. Granier
#     description:        Monthly nox expressed as nitric oxide emissions based...
#     product_version:    v6.2
#     title:              CAMS Global anthropogenic emissions
#     ...                 ...
#     source:             EDGARv6 emissions up to 2018 CAMS-GLOB-TEMPOv2.1/v3.2...
#     creation_date:      2023-11-21 UTC
#     NCO:                netCDF Operators version 5.1.4 (Homepage = http://nco...
#     distribution_date:  2025-10-14
#     references:         Soulie, A., Granier, C., Darras, S., Zilbermann, N., ...
#     history:            Tue Oct 14 15:20:07 2025: ncatted -O -a distribution_...

# %%
def centers_to_edges(arr):
    d = np.diff(arr)
    edges = np.empty(len(arr) + 1)
    edges[1:-1] = arr[:-1] + d / 2
    edges[0] = arr[0] - d[0] / 2
    edges[-1] = arr[-1] + d[-1] / 2
    return edges

def get_latlon_array(lat_range,lon_range):  # lon_range = [lon_min, lon_max], lat_range = [lat_min, lat_max]
     
    lat_range = np.array(lat_range)
    lon_range  = np.array(lon_range)
    
    lat_range_grid = np.ceil(lat_range * 120) * 1/120
    lon_range_grid = np.ceil(lon_range * 80) * 1/80

    #print(lat_range_grid)
    #print(lon_range_grid)
    
    lat_array = np.arange(lat_range_grid[0],lat_range_grid[1] + 1/120,  1/120 )
    lon_array  = np.arange(lon_range_grid[0],lon_range_grid[1] + 1/120 ,  1/80 )
    
    lat_array = np.round(lat_array, 5)
    lon_array = np.round(lon_array ,5)

    return lon_array, lat_array

# %%
# the input lon, lat is the center of 5 x 5 grid 
def cams_make(lon, lat, camsds,cams_pix = 5):
  
    # squeeze in case there are time/level dims
    camsds = camsds.squeeze()

    # get full CAMS coordinates
    src_lon = camsds['lon'].values
    src_lat = camsds['lat'].values
    src_val = 1e9 * 1e-2 * camsds['sum'].values  # (nlat, nlon)

    # --- 1. find nearest CAMS grid cell to (lon, lat) ---
    ix0 = np.argmin(np.abs(src_lon - lon))
    iy0 = np.argmin(np.abs(src_lat - lat))

    # --- 2. build 5x5 window around it ---
    half = cams_pix // 2  # =2

    ix = np.arange(ix0 - half, ix0 + half + 1)
    iy = np.arange(iy0 - half, iy0 + half + 1)

    # clip to domain (safety)
    ix = ix[(ix >= 0) & (ix < len(src_lon))]
    iy = iy[(iy >= 0) & (iy < len(src_lat))]

    # actual CAMS grid centers
    cams_lon_array = src_lon[ix]
    cams_lat_array = src_lat[iy]

    # extract CAMS emission subgrid
    cams_emission = src_val[np.ix_(iy, ix)]  # (5,5) if not at boundary

    #print("CAMS lon centers:", cams_lon_array)
    #print("CAMS lat centers:", cams_lat_array)
    #print("CAMS subgrid shape:", cams_emission.shape)
    # plt.imshow(cams_emission)
    # plt.show()
   
    return cams_lon_array, cams_lat_array, cams_emission

# %%
def eagrid_make(cams_lon_array, cams_lat_array,cams_emission, k, sector = "All_sources", source = 'NOx'):
    # = make downscaled grid made from original cams grid
    dlon = np.abs(cams_lon_array[1] - cams_lon_array[0])
    dlat = np.abs(cams_lat_array[1] - cams_lat_array[0])

    # build fine grid covering the 5 CAMS cells
    lon_min = cams_lon_array[0] - dlon / 2
    lon_max = cams_lon_array[-1] + dlon / 2
    lat_min = cams_lat_array[0] - dlat / 2
    lat_max = cams_lat_array[-1] + dlat / 2

    fine_dlon = dlon / k
    fine_dlat = dlat / k

    # The lat lon is the center of grid
    eagrid_lon_array = np.round(np.linspace(lon_min + fine_dlon/2, lon_max - fine_dlon/2, 5 * k), 4)
    eagrid_lat_array = np.round(np.linspace(lat_min + fine_dlat/2, lat_max - fine_dlat/2, 5 * k), 4)
    
    # Lon, Lat = np.meshgrid(eagrid_lon_array, eagrid_lat_array)
    # value_grid = np.zeros(Lon.shape, dtype = float)  # data will be stored 
    # area_grid  = np.zeros_like(value_grid) # area of overlap will be stored

    # print(f"cams_lat_array {len(cams_lat_array), cams_lat_array}")
    # print(f" first eagrid_lat_arra {eagrid_lat_array[0]}")
    # print(f" end eagrid_lat_array {eagrid_lat_array[-5:]}")
    # print(f" len of eagrid_lon_array {len(eagrid_lon_array)}")
    # print(f"first of eagrid_lon_array {eagrid_lon_array[:5]}")

    # == From here eagrid data is read == 
    sec_idx = int(ds.sector.to_index().get_loc(sector))
    src_idx = int(ds.source.to_index().get_loc(source))

    lat_e = ds["lat"].values
    lon_e = ds["lon"].values
    emission = ds["Emission"][sec_idx, src_idx, :].values

    # == mask ====
    # get a range from lat_array and lon_array
    margin = 0.05
    lat_min, lat_max = eagrid_lat_array[0], eagrid_lat_array[-1]
    lon_min, lon_max = eagrid_lon_array[0], eagrid_lon_array[-1]
    mask = (lat_e >= lat_min - margin) & (lat_e <= lat_max + margin) & \
           (lon_e >= lon_min - margin) & (lon_e <= lon_max + margin)
    # extract # lat_in, lon_in are left bottom
    lat_in = lat_e[mask]
    lon_in = lon_e[mask]

    emission_in = emission[mask]

    # # only keep points with no multiple values
    # coords = np.column_stack((lon_in,lat_in))
    # _, unique_idx = np.unique(coords, axis=0, return_index=True)

    # lon_in = lon_in[unique_idx]
    # lat_in = lat_in[unique_idx]
    # emission_in = emission_in[unique_idx]

    # TODO currently hard-corded, needs to be revisited
    #dlat_e = 1/240
    #dlon_e = 1/160
    lon_e_edges , lat_e_edges = get_latlon_array([lat_min , lat_max ],[lon_min , lon_max])  #
    lon_e_center = lon_e_edges + 1/160
    lat_e_center = lat_e_edges + 1/240
    #lat_e_edges = np.concatenate([lat_in - dlat_e, [lat_in.max() + dlat_e]])
    #lon_e_edges = np.concatenate([lon_in, [lon_in.max() + dlon_e]])
    #print(f" 10min eagrid nc's lon edges {lon_in[:10]}")
    #print(f" first  lon_e_edges, {lon_e_edges[:5]}")
    #print(f" end 5 of lon_e_edges, {lon_e_edges[-5:]}")
    #print(f"len of lot_e_edges {len(lon_e_edges)}")
    #print('')
    #print(f" first 5 of lat_e_edges, {lat_e_edges[:5]}")
    #print(f" end 5 of lat_e_edges, {lat_e_edges[-5:]}")
   # == Put emission in (point data into 2d array) ==
    Lon_in, Lat_in = np.meshgrid(lon_e_center, lat_e_center)
    emission_grid = np.full(Lon_in.shape, np.nan)
    for lon, lat, val in zip(lon_in, lat_in, emission_in):
        i = np.argmin(np.abs(lat_e_center - lat))
        # print(lat_array[i]- lat)   < = This is all 0, means lat_array made in def get_latlon_array is align with nc grid
        j = np.argmin(np.abs(lon_e_center - lon))
    #     if abs(lat_array[i] - lat) <= lat_half and abs(lon_array[j] - lon) <= lon_half:
        emission_grid[i, j] = val
        #print(val)
   # == =========
    #print(emission_grid.shape)
    #plt.imshow(emission_grid)
    #plt.show()

    # make the edge lon and lat of target grid (high reso but align eith cams)
    # to calculate the overlap between eagrid emission grid
    #print(f" len of eagrid_lon_array {len(eagrid_lon_array)}")
    #print(f" len of eagrid_lat_array {len(eagrid_lat_array)}")
    #lat_t_edges = centers_to_edges(eagrid_lat_array)
    #lon_t_edges = centers_to_edges(eagrid_lon_array)
    #print(f"first of lon e and t  {lon_e_edges[0], lon_t_edges[0]}")
    #print(f"end   of lon e and t {lon_e_edges[-1], lon_t_edges[-1]}")

    #print(f"first of lat e and t  {lat_e_edges[0], lat_t_edges[0]}")
    #print(f"end   of lat e and t {lat_e_edges[-1], lat_t_edges[-1]}")

   # print(f"len of lat_t_edges {len(lat_t_edges)}")
   # print(f"len of lon_t_edges {len(lon_t_edges)}")
    grid_in =  {'lon': lon_e_center, 'lat': lat_e_center}
    grid_out = {'lon': eagrid_lon_array, 'lat': eagrid_lat_array}

    regridder = xe.Regridder(grid_in,grid_out, 'conservative')
    value_grid = regridder(emission_grid)

    grid_in_cams = {'lon': cams_lon_array, 'lat': cams_lat_array}
    grid_out_cams ={'lon': eagrid_lon_array, 'lat': eagrid_lat_array}
    regridder_cams = xe.Regridder(grid_in_cams, grid_out_cams, 'conservative')
    fine_cams_emission = regridder_cams(cams_emission)
    print("cams before :", np.nansum(cams_emission))
    print("cams after :", np.nansum(fine_cams_emission))
    print('')
    print("eagrid Before:", np.nansum(emission_grid))
    print("eagrid After: ", np.nansum(value_grid))

    #plt.imshow(value_grid)
    #plt.show()

    return lon_e_center, lat_e_center, emission_grid, eagrid_lon_array, eagrid_lat_array, value_grid, fine_cams_emission

    # they are ok 
    # print("lat edges:", lat_t_edges[:5], "...", lat_t_edges[-5:])
    # print("lon edges:", lon_t_edges[:5], "...", lon_t_edges[-5:])
    # print("target lat centers:", eagrid_lat_array[:5], eagrid_lat_array[-5:])
    # print("target lon centers:", eagrid_lon_array[:5], eagrid_lon_array[-5:])
    return eagrid_lon_array, eagrid_lat_array, value_grid

# %%
cams_pix = 5
cams_lon_array, cams_lat_array, cams_emission= cams_make(135.345, 34.65,  camsds, cams_pix)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 cams_pix = 5
# ----> 2 cams_lon_array, cams_lat_array, cams_emission= cams_make(135.345, 34.65,  camsds, cams_pix)
#
# NameError: name 'camsds' is not defined

# %%
lon_e_center, lat_e_center, emission_grid, eagrid_lon_array, eagrid_lat_array, value_grid, fine_cams_emission = eagrid_make(cams_lon_array,cams_lat_array,10,  sector = "All_sources", source = 'NOx')

# cams compare 
fig, axes = plt.subplots(1, 2, figsize=(14, 7))  # 横並び2列、各7x7相当

# ------------------- before -------------------
ax = axes[0]
cmap = cm.roma_r
norm = mcolors.Normalize(vmin=2.5, vmax=6.5)

sc = ax.pcolormesh(cams_lon_array, cams_lat_array, np.log10(cams_emission),
                   cmap=cmap, norm=norm,
                   edgecolors='lightgray', linewidth=0.2)
ax.set(xlim=[cams_lon_array[0], cams_lon_array[-1]], ylim=[cams_lat_array[0], cams_lat_array[-1]])
cb = plt.colorbar(sc, ax=ax, shrink=0.7, aspect=20, fraction=0.046)
cb.ax.tick_params(labelsize=7)
cb.set_label('before', fontsize=7)
ax.set_title('Before', fontsize=10)

# ------------------- after -------------------
ax = axes[1]
sc = ax.pcolormesh(eagrid_lon_array, eagrid_lat_array, np.log10(fine_cams_emission),
                   cmap=cmap, norm=norm,
                   edgecolors='lightgray', linewidth=0.2)
ax.set(xlim=[eagrid_lon_array[0], eagrid_lon_array[-1]], ylim=[eagrid_lat_array[0], eagrid_lat_array[-1]])
cb = plt.colorbar(sc, ax=ax, shrink=0.7, aspect=20, fraction=0.046)
cb.ax.tick_params(labelsize=7)
cb.set_label('after', fontsize=7)
ax.set_title('After', fontsize=10)
plt.title('CAMS')
plt.tight_layout()
plt.show()



# == EAGrids before and after regridding =======
fig, axes = plt.subplots(1, 2, figsize=(14, 7))  # 横並び2列、各7x7相当

# ------------------- before -------------------
ax = axes[0]
cmap = cm.roma_r
norm = mcolors.Normalize(vmin=2.5, vmax=6.5)

sc = ax.pcolormesh(lon_e_center, lat_e_center, np.log10(emission_grid),
                   cmap=cmap, norm=norm,
                   edgecolors='lightgray', linewidth=0.2)
ax.set(xlim=[lon_e_center[0], lon_e_center[-1]], ylim=[lat_e_center[0], lat_e_center[-1]])
cb = plt.colorbar(sc, ax=ax, shrink=0.7, aspect=20, fraction=0.046)
cb.ax.tick_params(labelsize=7)
cb.set_label('before', fontsize=7)
ax.set_title('Before', fontsize=10)

# ------------------- after -------------------
ax = axes[1]
sc = ax.pcolormesh(eagrid_lon_array, eagrid_lat_array, np.log10(value_grid),
                   cmap=cmap, norm=norm,
                   edgecolors='lightgray', linewidth=0.2)
ax.set(xlim=[eagrid_lon_array[0], eagrid_lon_array[-1]], ylim=[eagrid_lat_array[0], eagrid_lat_array[-1]])
cb = plt.colorbar(sc, ax=ax, shrink=0.7, aspect=20, fraction=0.046)
cb.ax.tick_params(labelsize=7)
cb.set_label('after', fontsize=7)
ax.set_title('After', fontsize=10)

plt.title('EAGrid')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 lon_e_edges, lat_e_edges, emission_grid, eagrid_lon_array, eagrid_lat_array, value_grid = eagrid_make(cams_lon_array,cams_lat_array,10,  sector = "All_sources", source = 'NOx')
#       3 fig, axes = plt.subplots(1, 2, figsize=(14, 7))  # 横並び2列、各7x7相当
#       5 # ------------------- before -------------------
#
# NameError: name 'cams_lon_array' is not defined

# %%
def make_testdata(camsds, ds, cams_pix,  scale_factor , sector = "All_sources", source = 'NOx'):
    # == eagrid data read ===
    sec_idx = int(ds.sector.to_index().get_loc(sector))
    src_idx = int(ds.source.to_index().get_loc(source))

    lat_e = ds["lat"].values
    lon_e = ds["lon"].values
    emission = ds["Emission"][sec_idx, src_idx, :].values

    #lat_e_uni = np.unique(lat_e)
    #lon_e_uni = np.unique(lon_e)
    #emission_2d = emission.reshape(len(lat_e_uni),len(lon_e_uni))
    
    min_lon = np.min(lon_e)
    max_lon = np.max(lon_e)
    min_lat = np.min(lat_e)
    max_lat = np.max(lat_e)
    
    # ==========================
    lon_array = np.arange(min_lon , max_lon , 0.3)  #  cams grid is 0.1 degree
    lat_array = np.arange(min_lat , max_lat , 0.3)

    print(f"before removed {len(lon_array) , len(lat_array)}")

    dataset_lon_array = []   # THE array for the center lon lat of image, which has almost all data (less nan)
    dataset_lat_array = []
    
    for lon in lon_array:
        for lat in lat_array:
            half_size = cams_pix * 0.1 / 2  # as 5x5 of cams pixel, the hald degree is 0.25
            dlat = np.abs(lat_e - lat)
            dlon = np.abs(lon_e - lon)
            
            mask = (dlat <= half_size) & (dlon <= half_size)
         
            #print(f"len of mask (True count): {np.sum(mask)}")

            sub_points = emission[mask]
            total = sub_points.size
            if total == 0:
                continue
            if np.nansum(sub_points) < 100:
                continue

            
            invalid_mask = np.isnan(sub_points) | (sub_points == 0)
            ratio_invalid = invalid_mask.sum() / total

            if ratio_invalid < 0.5:
                dataset_lon_array.append(lon)
                dataset_lat_array.append(lat)
       
                
    print(f"len of LON LAT {len(dataset_lon_array), len(dataset_lat_array)}")            

    num_dataset = len(dataset_lon_array)
    cams_dataset = np.full([num_dataset, 5,5], np.nan)
    eagrid_dataset = np.full([num_dataset, 50, 50], np.nan)   # 3d (num of dataset, 50, 50)
    for i, (lon, lat) in enumerate(zip(dataset_lon_array, dataset_lat_array)):
        print(f"{lon:.3f}, {lat:.3f}")
        cams_lon_array, cams_lat_array, cams_emission = cams_make(lon, lat,  camsds, cams_pix)
        lon_e_edges, lat_e_edges, emission_grid, eagrid_lon_array, eagrid_lat_array, value_grid, fine_cams_emission = eagrid_make(cams_lon_array,cams_lat_array,10,  sector = "All_sources", source = 'NOx')
        cams_dataset[i] = cams_emission
        eagrid_dataset[i] = value_grid

    
        
    return cams_dataset, eagrid_dataset

# %%
make_testdata(camsds,ds, 5, 10, "All_sources", "NOx")
# Out:
# before removed (104, 72)
# len of LON LAT (681, 681)
# 122.825, 24.250
# first of lon e and t  (np.float64(122.6125), np.float64(122.60000610351562))
# end   of lon e and t (np.float64(123.09988), np.float64(123.10000610351562))
# first of lat e and t  (np.float64(24.00833), np.float64(24.0))
# end   of lat e and t (np.float64(24.49999), np.float64(24.5))
# Before: 137997.4779047966
# After:  137988.5655016899
# 122.825, 24.550
# first of lon e and t  (np.float64(122.6125), np.float64(122.60000610351562))
# end   of lon e and t (np.float64(123.09988), np.float64(123.10000610351562))
# first of lat e and t  (np.float64(24.30833), np.float64(24.299999237060547))
# end   of lat e and t (np.float64(24.79999), np.float64(24.799999237060547))
# Before: 137997.4779047966
# After:  137988.56550168994
# 123.125, 24.250
# first of lon e and t  (np.float64(122.9125), np.float64(122.89999389648438))
# end   of lon e and t (np.float64(123.39988), np.float64(123.39999389648438))
# first of lat e and t  (np.float64(24.00833), np.float64(24.0))
# end   of lat e and t (np.float64(24.49999), np.float64(24.5))
# Before: 137488.65006017685
# After:  137488.65006017685
# 123.125, 24.550
# first of lon e and t  (np.float64(122.9125), np.float64(122.89999389648438))
# end   of lon e and t (np.float64(123.39988), np.float64(123.39999389648438))
# first of lat e and t  (np.float64(24.30833), np.float64(24.299999237060547))
# end   of lat e and t (np.float64(24.79999), np.float64(24.799999237060547))
# Before: 137488.65006017685
# After:  137488.65006017685
# 123.725, 23.950
# first of lon e and t  (np.float64(123.5125), np.float64(123.5))
# end   of lon e and t (np.float64(123.99988), np.float64(124.0))
# first of lat e and t  (np.float64(23.70833), np.float64(23.700000762939453))
# end   of lat e and t (np.float64(24.19999), np.float64(24.200000762939453))
# Before: 7682.286982178688
# After:  7502.831188797951
# 124.025, 23.950
# first of lon e and t  (np.float64(123.8125), np.float64(123.80000305175781))
# end   of lon e and t (np.float64(124.29988), np.float64(124.29999542236328))
# first of lat e and t  (np.float64(23.70833), np.float64(23.700000762939453))
# end   of lat e and t (np.float64(24.19999), np.float64(24.200000762939453))
# Before: 2529.4870213270187
# After:  1170.688950419426
# 124.025, 24.250
# first of lon e and t  (np.float64(123.8125), np.float64(123.80000305175781))
# end   of lon e and t (np.float64(124.29988), np.float64(124.29999542236328))
# first of lat e and t  (np.float64(24.00833), np.float64(24.0))
# end   of lat e and t (np.float64(24.49999), np.float64(24.5))
# Before: 3012710.076539874
# After:  2907361.8701227903
# 124.025, 24.550
# first of lon e and t  (np.float64(123.8125), np.float64(123.80000305175781))
# end   of lon e and t (np.float64(124.29988), np.float64(124.29999542236328))
# first of lat e and t  (np.float64(24.30833), np.float64(24.299999237060547))
# end   of lat e and t (np.float64(24.79999), np.float64(24.799999237060547))
# Before: 3678470.0523252487
# After:  3285759.6032943726
# 124.325, 24.250
# first of lon e and t  (np.float64(124.1125), np.float64(124.10000610351562))
# end   of lon e and t (np.float64(124.59988), np.float64(124.60000610351562))
# first of lat e and t  (np.float64(24.00833), np.float64(24.0))
# end   of lat e and t (np.float64(24.49999), np.float64(24.5))
# Before: 2962067.117292404
# After:  2856718.9108753204
# 124.325, 24.550
# first of lon e and t  (np.float64(124.1125), np.float64(124.10000610351562))
# end   of lon e and t (np.float64(124.59988), np.float64(124.60000610351562))
# first of lat e and t  (np.float64(24.30833), np.float64(24.299999237060547))
# end   of lat e and t (np.float64(24.79999), np.float64(24.799999237060547))
# Before: 3859685.3876047134
# After:  3859685.387604713
# 124.325, 24.850
# first of lon e and t  (np.float64(124.1125), np.float64(124.10000610351562))
# end   of lon e and t (np.float64(124.59988), np.float64(124.60000610351562))
# first of lat e and t  (np.float64(24.60833), np.float64(24.599998474121094))
# end   of lat e and t (np.float64(25.09999), np.float64(25.099998474121094))
# Before: 83.55988121032715
# After:  83.55988121032715
# 124.625, 24.550
# first of lon e and t  (np.float64(124.4125), np.float64(124.39999389648438))
# end   of lon e and t (np.float64(124.89988), np.float64(124.89999389648438))
# first of lat e and t  (np.float64(24.30833), np.float64(24.299999237060547))
# end   of lat e and t (np.float64(24.79999), np.float64(24.799999237060547))
# Before: 66255.09351205826
# After:  66255.09351205826
# 124.625, 24.850
# first of lon e and t  (np.float64(124.4125), np.float64(124.39999389648438))
# end   of lon e and t (np.float64(124.89988), np.float64(124.89999389648438))
# first of lat e and t  (np.float64(24.60833), np.float64(24.599998474121094))
# end   of lat e and t (np.float64(25.09999), np.float64(25.099998474121094))
# Before: 66002.44223022461
# After:  66002.44223022461
# 124.925, 24.550
# first of lon e and t  (np.float64(124.7125), np.float64(124.70000457763672))
# end   of lon e and t (np.float64(125.19988), np.float64(125.19999694824219))
# first of lat e and t  (np.float64(24.30833), np.float64(24.299999237060547))
# end   of lat e and t (np.float64(24.79999), np.float64(24.799999237060547))
# Before: 18786.30156326294
# After:  7319.358600616457
# 124.925, 24.850
# first of lon e and t  (np.float64(124.7125), np.float64(124.70000457763672))
# end   of lon e and t (np.float64(125.19988), np.float64(125.19999694824219))
# first of lat e and t  (np.float64(24.60833), np.float64(24.599998474121094))
# end   of lat e and t (np.float64(25.09999), np.float64(25.099998474121094))
# Before: 81578.70246982574
# After:  67139.74538135529
# 125.225, 24.550
# first of lon e and t  (np.float64(125.0125), np.float64(125.0))
# end   of lon e and t (np.float64(125.49988), np.float64(125.5))
# first of lat e and t  (np.float64(24.30833), np.float64(24.299999237060547))
# end   of lat e and t (np.float64(24.79999), np.float64(24.799999237060547))
# Before: 534212.9747362137
# After:  519471.0821151734
# 125.225, 24.850
# first of lon e and t  (np.float64(125.0125), np.float64(125.0))
# end   of lon e and t (np.float64(125.49988), np.float64(125.5))
# first of lat e and t  (np.float64(24.60833), np.float64(24.599998474121094))
# end   of lat e and t (np.float64(25.09999), np.float64(25.099998474121094))
# Before: 2480422.254507065
# After:  2480422.2545070644
# 125.225, 25.150
# first of lon e and t  (np.float64(125.0125), np.float64(125.0))
# end   of lon e and t (np.float64(125.49988), np.float64(125.5))
# first of lat e and t  (np.float64(24.90833), np.float64(24.900001525878906))
# end   of lat e and t (np.float64(25.39999), np.float64(25.400001525878906))
# Before: 8336.531826019287
# After:  8336.531826019287
# 125.525, 24.550
# first of lon e and t  (np.float64(125.3125), np.float64(125.30000305175781))
# end   of lon e and t (np.float64(125.79988), np.float64(125.79999542236328))
# first of lat e and t  (np.float64(24.30833), np.float64(24.299999237060547))
# end   of lat e and t (np.float64(24.79999), np.float64(24.799999237060547))
# Before: 195931.16937446594
# After:  191214.97875404358
# 125.525, 24.850
# first of lon e and t  (np.float64(125.3125), np.float64(125.30000305175781))
# end   of lon e and t (np.float64(125.79988), np.float64(125.79999542236328))
# first of lat e and t  (np.float64(24.60833), np.float64(24.599998474121094))
# end   of lat e and t (np.float64(25.09999), np.float64(25.099998474121094))
# Before: 220157.25835704803
# After:  220157.25835704806
# 125.525, 25.150
# first of lon e and t  (np.float64(125.3125), np.float64(125.30000305175781))
# end   of lon e and t (np.float64(125.79988), np.float64(125.79999542236328))
# first of lat e and t  (np.float64(24.90833), np.float64(24.900001525878906))
# end   of lat e and t (np.float64(25.39999), np.float64(25.400001525878906))
# Before: 2772.9193115234375
# After:  2772.9193115234375
# 126.425, 26.050
# first of lon e and t  (np.float64(126.2125), np.float64(126.20000457763672))
# end   of lon e and t (np.float64(126.69988), np.float64(126.69999694824219))
# first of lat e and t  (np.float64(25.80833), np.float64(25.799999237060547))
# end   of lat e and t (np.float64(26.29999), np.float64(26.299999237060547))
# Before: 10549.522964477539
# After:  1787.9104309082031
# 126.425, 26.350
# first of lon e and t  (np.float64(126.2125), np.float64(126.20000457763672))
# end   of lon e and t (np.float64(126.69988), np.float64(126.69999694824219))
# first of lat e and t  (np.float64(26.10833), np.float64(26.099998474121094))
# end   of lat e and t (np.float64(26.59999), np.float64(26.599998474121094))
# Before: 18618.35977935791
# After:  3412.439727783203
# 126.725, 26.050
# first of lon e and t  (np.float64(126.5125), np.float64(126.5))
# end   of lon e and t (np.float64(126.99988), np.float64(127.0))
# first of lat e and t  (np.float64(25.80833), np.float64(25.799999237060547))
# end   of lat e and t (np.float64(26.29999), np.float64(26.299999237060547))
# Before: 50273.56666183472
# After:  2237.2452087402344
# 126.725, 26.350
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 make_testdata(camsds,ds, 5, 10, "All_sources", "NOx")
#
# Cell In[10], line 61, in make_testdata(camsds, ds, cams_pix, scale_factor, sector, source)
#      59 for i, (lon, lat) in enumerate(zip(dataset_lon_array, dataset_lat_array)):
#      60     print(f"{lon:.3f}, {lat:.3f}")
# ---> 61     cams_lon_array, cams_lat_array, cams_emission = cams_make(lon, lat,  camsds, cams_pix)
#      62     lon_e_edges, lat_e_edges, emission_grid, eagrid_lon_array, eagrid_lat_array, value_grid = eagrid_make2(cams_lon_array,cams_lat_array,10,  sector = "All_sources", source = 'NOx')
#      63     cams_dataset[i] = cams_emission
#
# Cell In[4], line 10, in cams_make(lon, lat, camsds, cams_pix)
#       8 src_lon = camsds['lon'].values
#       9 src_lat = camsds['lat'].values
# ---> 10 src_val = 1e9 * 1e-2 * camsds['sum'].values  # (nlat, nlon)
#      12 # --- 1. find nearest CAMS grid cell to (lon, lat) ---
#      13 ix0 = np.argmin(np.abs(src_lon - lon))
#
# File ~/MasterThesis/EAGrid_data/data_create/eagrid_venv/lib/python3.9/site-packages/xarray/core/dataarray.py:801, in DataArray.values(self)
#     788 @property
#     789 def values(self) -> np.ndarray:
#     790     """
#     791     The array's data converted to numpy.ndarray.
#     792
#    (...)
#     799     to this array may be reflected in the DataArray as well.
#     800     """
# --> 801     return self.variable.values
#
# File ~/MasterThesis/EAGrid_data/data_create/eagrid_venv/lib/python3.9/site-packages/xarray/core/variable.py:541, in Variable.values(self)
#     538 @property
#     539 def values(self):
#     540     """The variable's data as a numpy.ndarray"""
# --> 541     return _as_array_or_item(self._data)
#
# File ~/MasterThesis/EAGrid_data/data_create/eagrid_venv/lib/python3.9/site-packages/xarray/core/variable.py:339, in _as_array_or_item(data)
#     325 def _as_array_or_item(data):
#     326     """Return the given values as a numpy array, or as an individual item if
#     327     it's a 0d datetime64 or timedelta64 array.
#     328
#    (...)
#     337     TODO: remove this (replace with np.asarray) once these issues are fixed
#     338     """
# --> 339     data = np.asarray(data)
#     340     if data.ndim == 0:
#     341         if data.dtype.kind == "M":
#
# File ~/MasterThesis/EAGrid_data/data_create/eagrid_venv/lib/python3.9/site-packages/xarray/core/indexing.py:834, in MemoryCachedArray.__array__(self, dtype)
#     833 def __array__(self, dtype: np.typing.DTypeLike = None) -> np.ndarray:
# --> 834     return np.asarray(self.get_duck_array(), dtype=dtype)
#
# File ~/MasterThesis/EAGrid_data/data_create/eagrid_venv/lib/python3.9/site-packages/xarray/core/indexing.py:837, in MemoryCachedArray.get_duck_array(self)
#     836 def get_duck_array(self):
# --> 837     self._ensure_cached()
#     838     return self.array.get_duck_array()
#
# File ~/MasterThesis/EAGrid_data/data_create/eagrid_venv/lib/python3.9/site-packages/xarray/core/indexing.py:831, in MemoryCachedArray._ensure_cached(self)
#     830 def _ensure_cached(self):
# --> 831     self.array = as_indexable(self.array.get_duck_array())
#
# File ~/MasterThesis/EAGrid_data/data_create/eagrid_venv/lib/python3.9/site-packages/xarray/core/indexing.py:788, in CopyOnWriteArray.get_duck_array(self)
#     787 def get_duck_array(self):
# --> 788     return self.array.get_duck_array()
#
# File ~/MasterThesis/EAGrid_data/data_create/eagrid_venv/lib/python3.9/site-packages/xarray/core/indexing.py:651, in LazilyIndexedArray.get_duck_array(self)
#     647     array = apply_indexer(self.array, self.key)
#     648 else:
#     649     # If the array is not an ExplicitlyIndexedNDArrayMixin,
#     650     # it may wrap a BackendArray so use its __getitem__
# --> 651     array = self.array[self.key]
#     653 # self.array[self.key] is now a numpy array when
#     654 # self.array is a BackendArray subclass
#     655 # and self.key is BasicIndexer((slice(None, None, None),))
#     656 # so we need the explicit check for ExplicitlyIndexed
#     657 if isinstance(array, ExplicitlyIndexed):
#
# File ~/MasterThesis/EAGrid_data/data_create/eagrid_venv/lib/python3.9/site-packages/xarray/backends/netCDF4_.py:100, in NetCDF4ArrayWrapper.__getitem__(self, key)
#      99 def __getitem__(self, key):
# --> 100     return indexing.explicit_indexing_adapter(
#     101         key, self.shape, indexing.IndexingSupport.OUTER, self._getitem
#     102     )
#
# File ~/MasterThesis/EAGrid_data/data_create/eagrid_venv/lib/python3.9/site-packages/xarray/core/indexing.py:1015, in explicit_indexing_adapter(key, shape, indexing_support, raw_indexing_method)
#     993 """Support explicit indexing by delegating to a raw indexing method.
#     994
#     995 Outer and/or vectorized indexers are supported by indexing a second time
#    (...)
#    1012 Indexing result, in the form of a duck numpy-array.
#    1013 """
#    1014 raw_key, numpy_indices = decompose_indexer(key, shape, indexing_support)
# -> 1015 result = raw_indexing_method(raw_key.tuple)
#    1016 if numpy_indices.tuple:
#    1017     # index the loaded np.ndarray
#    1018     indexable = NumpyIndexingAdapter(result)
#
# File ~/MasterThesis/EAGrid_data/data_create/eagrid_venv/lib/python3.9/site-packages/xarray/backends/netCDF4_.py:113, in NetCDF4ArrayWrapper._getitem(self, key)
#     111     with self.datastore.lock:
#     112         original_array = self.get_array(needs_lock=False)
# --> 113         array = getitem(original_array, key)
#     114 except IndexError:
#     115     # Catch IndexError in netCDF4 and return a more informative
#     116     # error message.  This is most often called when an unsorted
#     117     # indexer is used before the data is loaded from disk.
#     118     msg = (
#     119         "The indexing operation you are attempting to perform "
#     120         "is not valid on netCDF4.Variable object. Try loading "
#     121         "your data into memory first by calling .load()."
#     122     )
#
# KeyboardInterrupt:
